# %% [markdown]
# # Final Project: Email Spam Detection
# ## By Brandon Stanyer

# %% [markdown]
# ## Preprocessing: Read & Tokenize Data
# initially, we will read in the corpus of emails provided from the Enron public email corpus. Emails are currently is a raw format, with subjects, ccs, dates and all. The emails are in two folders: Spam & Ham, where spam represents malicious or fake emails and ham represents authentic emails. For this analysis, we import 1000 of each type, but that can be modified.

# %%
# open python and nltk packages needed for processing
import os
import sys
import random
import nltk
from nltk.corpus import stopwords
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter
import math
from nltk.corpus import sentence_polarity
import pandas as pd

# %%
# define a path to the corpus
dirPath = '/Users/bstanyer/Desktop/IST 664 - Natural Language Processing/Final Project/FinalProjectData/EmailSpamCorpora/corpus'
# choose a number of emails to import
limitStr = 1000

# %%
# start lists for spam and ham email texts
hamtexts = []
spamtexts = []

# function to read spam and ham files, train and test a classifier 
def processspamham(dirPath,limitStr):
    # convert the limit argument from a string to an int
    limit = int(limitStr)
    
    os.chdir(dirPath)
    # process all files in directory that end in .txt up to the limit
    #    assuming that the emails are sufficiently randomized
    for file in os.listdir("./spam"):
        if (file.endswith(".txt")) and (len(spamtexts) < limit):
            # open file for reading and read entire file into a string
            f = open("./spam/"+file, 'r', encoding="latin-1")
            spamtexts.append (f.read())
            f.close()
    for file in os.listdir("./ham"):
        if (file.endswith(".txt")) and (len(hamtexts) < limit):
            # open file for reading and read entire file into a string
            f = open("./ham/"+file, 'r', encoding="latin-1")
            hamtexts.append (f.read())
            f.close()

# %%
processspamham(dirPath, limitStr)

# %%
# print number of emails read
print ("Number of spam files:",len(spamtexts))
print ("Number of ham files:",len(hamtexts))
# Out:
# Number of spam files: 1000
# Number of ham files: 1000

# %%
# create list of mixed spam and ham email documents as (list of words, label)
emaildocs = []

# add all the spam
for spam in spamtexts:
    tokens = nltk.word_tokenize(spam)
    emaildocs.append((tokens, 'spam'))

# add all the regular emails
for ham in hamtexts:
    tokens = nltk.word_tokenize(ham)
    emaildocs.append((tokens, 'ham'))
    
len(emaildocs)
# Out:
# 2000

# %%
# randomize the list
random.seed(9)
random.shuffle(emaildocs)

# %%
# print a few token lists
for email in emaildocs[:2]:
    print (email)
# Out:
# (['Subject', ':', 'a', 'computer', 'and', 'internet', 'connection', 'for', 'you', 'and', 'your', 'family', 'as', 'you', 'know', ',', 'technology', 'is', 'critical', 'to', 'enron', ';', 'it', 'drives', 'our', 'success', 'and', 'will', 'continue', 'to', 'do', 'so', 'in', 'the', 'future', '.', 'technology', 'has', 'helped', 'enron', 'create', 'new', 'businesses', 'like', 'enron', 'broadband', 'services', 'and', 'enron', 'net', 'works', ',', 'and', 'it', 'is', 'responsible', 'for', 'applications', 'such', 'as', 'enrononline', 'and', 'enroncredit', '.', 'com', '.', 'you', '\x01', ',', 've', 'seen', 'what', 'technology', 'can', 'do', 'at', 'work', '.', 'now', 'we', 'want', 'you', 'and', 'your', 'family', 'to', 'realize', 'its', 'benefits', 'at', 'home', '.', 'with', 'that', 'in', 'mind', ',', 'we', 'are', 'excited', 'to', 'let', 'you', 'know', 'that', 'we', 'are', 'introducing', 'the', 'clickathome', 'program', ',', 'which', 'will', 'give', 'each', 'employee', 'a', 'computer', 'for', 'use', 'at', 'home', '.', 'where', 'technology', 'permits', ',', 'we', 'will', 'also', 'subsidize', 'an', 'internet', 'connection', '.', 'with', 'the', 'click', 'of', 'a', 'mouse', ',', 'a', 'home', 'computer', 'plus', 'internet', 'access', 'will', 'put', 'a', 'world', 'of', 'internet', 'knowledge', 'at', 'your', 'family', '\x01', ',', 's', 'fingertips', '.', 'we', 'have', 'just', 'signed', 'an', 'agreement', 'with', 'dell', 'computer', 'corporation', 'to', 'provide', 'the', 'computer', 'hardware', '.', 'we', 'wanted', 'to', 'let', 'you', 'know', 'about', 'the', 'program', 'now', 'in', 'case', 'you', 'and', 'your', 'family', 'were', 'considering', 'the', 'purchase', 'or', 'upgrade', 'of', 'a', 'home', 'computer', 'or', 'internet', 'connection', 'in', 'the', 'next', 'few', 'months', '.', 'the', 'scope', 'of', 'clickathome', 'includes', 'the', 'following', ':', '?', 'basic', 'package', ':', 'dell', 'desktop', 'computer', 'with', 'a', 'high', '-', 'speed', 'processor', ',', 'floppy', 'disk', 'drive', ',', 'mouse', ',', 'speakers', ',', 'monitor', ',', 'modem', ',', 'cd', '-', 'rom', 'drive', 'and', 'windows', '2000', 'software', '.', 'employees', 'will', 'have', 'the', 'option', 'to', 'receive', 'a', 'subsidized', 'internet', 'connection', ',', 'including', 'broadband', ',', 'where', 'commercially', 'available', '.', '?', 'participation', ':', 'this', 'program', 'will', 'be', 'available', 'to', 'active', 'regular', 'full', '-', 'time', 'and', 'regular', 'part', '-', 'time', 'employees', 'of', 'enron', 'and', 'its', 'wholly', 'owned', 'subsidiaries', ';', 'however', ',', 'employees', 'of', 'some', 'enron', 'companies', '(', 'portland', 'general', 'electric', ',', 'eott', ',', 'enron', 'facility', 'services', ')', 'may', 'not', 'be', 'able', 'to', 'participate', 'due', 'to', 'legal', ',', 'accounting', ',', 'tax', ',', 'labor', 'or', 'business', 'reasons', '.', 'eligibility', 'includes', 'being', 'employed', 'at', 'the', 'time', 'of', 'implementation', '.', '?', 'timing', ':', 'u', '.', 's', '.', 'employee', 'sign', '-', 'up', 'will', 'begin', 'in', 'early', '2001', ',', 'with', 'delivery', 'of', 'the', 'equipment', 'and', 'internet', 'connection', 'to', 'follow', 'shortly', 'thereafter', '.', 'delivery', 'of', 'equipment', 'to', 'participating', 'non', '-', 'u', '.', 's', '.', 'employees', 'is', 'targeted', 'for', 'late', '2001', '.', 'details', 'about', 'this', 'program', 'are', 'still', 'being', 'finalized', '.', 'to', 'address', 'some', 'of', 'your', 'initial', 'questions', ',', 'we', '\x01', ',', 've', 'posted', 'a', 'question', '-', 'and', '-', 'answer', 'document', 'on', 'http', ':', '/', '/', 'clickathome', '.', 'enron', '.', 'com', '.', 'we', 'will', 'schedule', 'an', 'espeak', 'session', 'in', 'the', 'near', 'future', 'where', 'you', 'will', 'have', 'an', 'opportunity', 'to', 'ask', 'questions', '.', 'or', ',', 'you', 'can', 'submit', 'your', 'questions', 'and', 'comments', 'to', 'clickathome', '@', 'enron', '.', 'com', '.', 'we', 'are', 'excited', ...
# (['Subject', ':', 'do', 'you', 'own', 'a', 'car', ';', 'starting', 'december', '7', 'th', 'ford', 'motor', 'company', 'reviews', '-', 'do', 'you', 'have', 'a', 'car', '?', 'the', 'new', 'energy', 'and', 'fossil', '-', 'fuel', 'reduction', 'systems', 'up', 'to', '60', 'percent', 'reduction', 'in', 'car', 'costs', 'create', 'an', '0', '.', 'r', '.', 'd', '.', 'e', '.', 'r', ':', 'http', ':', '/', '/', 'cyberbargain', '.', 'biz', '/', 'to', 'enough', ':', 'http', ':', '/', '/', 'cyberbargain', '.', 'biz', '/', 'r', 'updates', 'your', 'details', 'donald', 'covington', 'executioner', 'multicell', 'technologies', ',', 'inc', '.', ',', 'warwick', ',', '02886', ',', 'united', 'states', 'of', 'america', 'phone', ':', '298', '-', '777', '-', '1151', 'mobile', ':', '824', '-', '635', '-', '4731', 'email', ':', 'angkymc', '@', 'earth', '9', '.', 'com', 'this', 'is', 'an', 'auto', '-', 'generated', 'message', '-', 'please', 'do', 'not', 'reply', 'to', 'this', 'message', 'this', 'software', 'is', 'a', '58', 'decade', 'complementary', 'version', 'notes', ':', 'the', 'contents', 'of', 'this', 'message', 'is', 'for', 'your', 'exclusive', 'use', 'and', 'should', 'not', 'be', 'affluence', 'uruguay', 'sawfly', 'salami', 'restaurant', 'time', ':', 'wed', ',', '08', 'dec', '2004', '18', ':', '04', ':', '57', '+', '0200'], 'spam')

# %% [markdown]
# # Experiment 1: Bag of Words Features
# ### Using the presence of words for Classification

# %%
# We will first start with bag of words feature sets
# The presence of the most common words will become email features
just_words = [word for words,label in emaildocs for word in words]
just_words[:50]
# Out:
# ['Subject',
#  ':',
#  'a',
#  'computer',
#  'and',
#  'internet',
#  'connection',
#  'for',
#  'you',
#  'and',
#  'your',
#  'family',
#  'as',
#  'you',
#  'know',
#  ',',
#  'technology',
#  'is',
#  'critical',
#  'to',
#  'enron',
#  ';',
#  'it',
#  'drives',
#  'our',
#  'success',
#  'and',
#  'will',
#  'continue',
#  'to',
#  'do',
#  'so',
#  'in',
#  'the',
#  'future',
#  '.',
#  'technology',
#  'has',
#  'helped',
#  'enron',
#  'create',
#  'new',
#  'businesses',
#  'like',
#  'enron',
#  'broadband',
#  'services',
#  'and',
#  'enron',
#  'net']

# %%
# using ALL words as features 
word_features = just_words
print(word_features[:100])
# Out:
# ['Subject', ':', 'a', 'computer', 'and', 'internet', 'connection', 'for', 'you', 'and', 'your', 'family', 'as', 'you', 'know', ',', 'technology', 'is', 'critical', 'to', 'enron', ';', 'it', 'drives', 'our', 'success', 'and', 'will', 'continue', 'to', 'do', 'so', 'in', 'the', 'future', '.', 'technology', 'has', 'helped', 'enron', 'create', 'new', 'businesses', 'like', 'enron', 'broadband', 'services', 'and', 'enron', 'net', 'works', ',', 'and', 'it', 'is', 'responsible', 'for', 'applications', 'such', 'as', 'enrononline', 'and', 'enroncredit', '.', 'com', '.', 'you', '\x01', ',', 've', 'seen', 'what', 'technology', 'can', 'do', 'at', 'work', '.', 'now', 'we', 'want', 'you', 'and', 'your', 'family', 'to', 'realize', 'its', 'benefits', 'at', 'home', '.', 'with', 'that', 'in', 'mind', ',', 'we', 'are', 'excited']

# %%
# define features (keywords) of a document
# each feature is 'contains(keyword)' and is true or false depending on whether that keyword is in the document
def email_features(email, word_features):
	email_words = set(email)
	features = {}
	for word in word_features:
		features['V_%s' % word] = (word in email_words)
	return features

# %%
# get features sets for a document, including keyword features and category feature
featuresets = [(email_features(d, word_features), c) for (d,c) in emaildocs]

# %%
# This shows an example of a featureset for an email
featuresets[:1]
# Out:
# [({'V_Subject': True,
#    'V_:': True,
#    'V_a': True,
#    'V_computer': True,
#    'V_and': True,
#    'V_internet': True,
#    'V_connection': True,
#    'V_for': True,
#    'V_you': True,
#    'V_your': True,
#    'V_family': True,
#    'V_as': True,
#    'V_know': True,
#    'V_,': True,
#    'V_technology': True,
#    'V_is': True,
#    'V_critical': True,
#    'V_to': True,
#    'V_enron': True,
#    'V_;': True,
#    'V_it': True,
#    'V_drives': True,
#    'V_our': True,
#    'V_success': True,
#    'V_will': True,
#    'V_continue': True,
#    'V_do': True,
#    'V_so': True,
#    'V_in': True,
#    'V_the': True,
#    'V_future': True,
#    'V_.': True,
#    'V_has': True,
#    'V_helped': True,
#    'V_create': True,
#    'V_new': True,
#    'V_businesses': True,
#    'V_like': True,
#    'V_broadband': True,
#    'V_services': True,
#    'V_net': True,
#    'V_works': True,
#    'V_responsible': True,
#    'V_applications': True,
#    'V_such': True,
#    'V_enrononline': True,
#    'V_enroncredit': True,
#    'V_com': True,
#    'V_\x01': True,
#    'V_ve': True,
#    'V_seen': True,
#    'V_what': True,
#    'V_can': True,
#    'V_at': True,
#    'V_work': True,
#    'V_now': True,
#    'V_we': True,
#    'V_want': True,
#    'V_realize': True,
#    'V_its': True,
#    'V_benefits': True,
#    'V_home': True,
#    'V_with': True,
#    'V_that': True,
#    'V_mind': True,
#    'V_are': True,
#    'V_excited': True,
#    'V_let': True,
#    'V_introducing': True,
#    'V_clickathome': True,
#    'V_program': True,
#    'V_which': True,
#    'V_give': True,
#    'V_each': True,
#    'V_employee': True,
#    'V_use': True,
#    'V_where': True,
#    'V_permits': True,
#    'V_also': True,
#    'V_subsidize': True,
#    'V_an': True,
#    'V_click': True,
#    'V_of': True,
#    'V_mouse': True,
#    'V_plus': True,
#    'V_access': True,
#    'V_put': True,
#    'V_world': True,
#    'V_knowledge': True,
#    'V_s': True,
#    'V_fingertips': True,
#    'V_have': True,
#    'V_just': True,
#    'V_signed': True,
#    'V_agreement': True,
#    'V_dell': True,
#    'V_corporation': True,
#    'V_provide': True,
#    'V_hardware': True,
#    'V_wanted': True,
#    'V_about': True,
#    'V_case': True,
#    'V_were': True,
#    'V_considering': True,
#    'V_purchase': True,
#    'V_or': True,
#    'V_upgrade': True,
#    'V_next': True,
#    'V_few': True,
#    'V_months': True,
#    'V_scope': True,
#    'V_includes': True,
#    'V_following': True,
#    'V_?': True,
#    'V_basic': True,
#    'V_package': True,
#    'V_desktop': True,
#    'V_high': True,
#    'V_-': True,
#    'V_speed': True,
#    'V_processor': True,
#    'V_floppy': True,
#    'V_disk': True,
#    'V_drive': True,
#    'V_speakers': True,
#    'V_monitor': True,
#    'V_modem': True,
#    'V_cd': True,
#    'V_rom': True,
#    'V_windows': True,
#    'V_2000': True,
#    'V_software': True,
#    'V_employees': True,
#    'V_option': True,
#    'V_receive': True,
#    'V_subsidized': True,
#    'V_including': True,
#    'V_commercially': True,
#    'V_available': True,
#    'V_participation': True,
#    'V_this': True,
#    'V_be': True,
#    'V_active': True,
#    'V_regular': True,
#    'V_full': True,
#    'V_time': True,
#    'V_part': True,
#    'V_wholly': True,
#    'V_owned': True,
#    'V_subsidiaries': True,
#    'V_however': True,
#    'V_some': True,
#    'V_companies': True,
#    'V_(': True,
#    'V_portland': True,
#    'V_general': True,
#    'V_electric': True,
#    'V_eott': True,
#    'V_facility': True,
#    'V_)': True,
#    'V_may': True,
#    'V_not': True,
#    'V_able': True,
#    'V_participate': True,
#    'V_due': True,
#    'V_legal': True,
#    'V_accounting': True,
#    'V_tax': True,
#    'V_labor': True,
#    'V_business': True,
#    'V_reasons': True,
#    'V_eligibility': True,
#    'V_being': True,
#    'V_employed': True,
#    'V_implementation': True,
#    'V_timing': True,
#    'V_u': True,
#    'V_sign': True,
#    'V_up': True,
#    'V_begin': True,
#    'V_early': True,
#    'V_2001': True,
#    'V_delivery': True,
#    'V_equipment': True,
#    'V_follow': True,
#    'V_shortly': True,
#    'V_thereafter': True,
#    'V_participating': True,
#    'V_non': True,
#    'V_targeted': True,
#    'V_late': True,
#    'V_details': True,
#    'V_still': True,
#    'V_finalized': True,
#    'V_address': True,
#    'V_initial': True,
#    'V_questions': True,
#    'V_posted': True,
#    'V_question': True,
#    'V_answer': True,
#    'V_document': True,
#    'V_on': True,
#    'V_http': True,
#    'V_/': True,
#    'V_schedule': True,
#    'V_espeak': True,
#    'V_session': True,
#    'V_near': True,
#    'V_opportunity': True,
#    'V_ask': True,
#    'V_submit': True,
#    'V_comments': True,
#    'V_@': True,
#    'V_extend': True,
#    'V_investment': True,
#    'V_believe': True,
#    'V_takes': True,
#    'V_communication': True,
#    'V_level': True,
#    'V_by': True,
#    'V_creating': True,
#    'V_endless': True,
#    'V_possibilities': True,
#    'V_experience': True,
#    'V_revolution': True,
#    'V_another': True,
#    'V_reason': True,
#    'V_why': True,
#    'V_great': True,
#    'V_place': True,
#    'V_own': False,
#    'V_car': False,
#    'V_starting': False,
#    'V_december': False,
#    'V_7': False,
#    'V_th': False,
#    'V_ford': False,
#    'V_motor': False,
#    'V_company': False,
#    'V_reviews': False,
#    'V_energy': False,
#    'V_fossil': False,
#    'V_fuel': False,
#    'V_reduction': False,
#    'V_systems': False,
#    'V_60': False,
#    'V_percent': False,
#    'V_costs': False,
#    'V_0': False,
#    'V_r': False,
#    'V_d': False,
#    'V_e': False,
#    'V_cyberbargain': False,
#    'V_biz': False,
#    'V_enough': False,
#    'V_updates': False,
#    'V_donald': False,
#    'V_covington': False,
#    'V_executioner': False,
#    'V_multicell': False,
#    'V_technologies': False,
#    'V_inc': False,
#    'V_warwick': False,
#    'V_02886': False,
#    'V_united': False,
#    'V_states': False,
#    'V_america': False,
#    'V_phone': False,
#    'V_298': False,
#    'V_777': False,
#    'V_1151': False,
#    'V_mobile': False,
#    'V_824': False,
#    'V_635': False,
#    'V_4731': False,
#    'V_email': False,
#    'V_angkymc': False,
#    'V_earth': False,
#    'V_9': False,
#    'V_auto': False,
#    'V_generated': False,
#    'V_message': False,
#    'V_please': False,
#    'V_reply': False,
#    'V_58': False,
#    'V_decade': False,
#    'V_complementary': False,
#    'V_version': False,
#    'V_notes': False,
#    'V_contents': False,
#    'V_exclusive': False,
#    'V_should': False,
#    'V_affluence': False,
#    'V_uruguay': False,
#    'V_sawfly': False,
#    'V_salami': False,
#    'V_restaurant': False,
#    'V_wed': False,
#    'V_08': False,
#    'V_dec': False,
#    'V_2004': False,
#    'V_18': False,
#    'V_04': False,
#    'V_57': False,
#    'V_+': False,
#    'V_0200': False,
#    'V_hpl': False,
#    'V_nom': False,
#    'V_14': False,
#    'V_see': False,
#    'V_attached': False,
#    'V_file': False,
#    'V_hplnl': False,
#    'V_214': False,
#    'V_xls': False,
#    'V_re': False,
#    'V_how': False,
#    'V_i': False,
#    'V_made': False,
#    'V_money': False,
#    'V_porn': False,
#    'V_make': False,
#    'V_$': False,
#    'V_1000': False,
#    'V_day': False,
#    'V_adult': False,
#    'V_industry': False,
#    'V_bring': False,
#    'V_riches': False,
#    'V_beyond': False,
#    'V_wildest': False,
#    'V_dreams': False,
#    'V_little': False,
#    'V_no': False,
#    'V_show': False,
#    'V_!': False,
#    'V_fortune': False,
#    'V_become': False,
#    'V_webmaster': False,
#    'V_if': False,
#    'V_would': False,
#    'V_prefer': False,
#    'V_these': False,
#    'V_messages': False,
#    'V_check': False,
#    'V_here': False,
#    'V_removed': False,
#    'V_within': False,
#    'V_48': False,
#    'V_hrs': False,
#    'V_get': False,
#    'V_8434': False,
#    'V_people': False,
#    'V_nowthe': False,
#    'V_weather': False,
#    'V_climate': False,
#    'V_any': False,
#    'V_particular': False,
#    'V_environment': False,
#    'V_change': False,
#    'V_affect': False,
#    'V_eat': False,
#    'V_much': False,
#    'V_they': False,
#    'V_calpine': False,
#    'V_daily': False,
#    'V_gas': False,
#    'V_nomination': False,
#    'V_>': False,
#    'V_ricky': False,
#    'V_archer': False,
#    'V_supply': False,
#    'V_700': False,
#    'V_louisiana': False,
#    'V_suite': False,
#    'V_2700': False,
#    'V_houston': False,
#    'V_texas': False,
#    'V_77002': False,
#    'V_713': False,
#    'V_830': False,
#    'V_8659': False,
#    'V_direct': False,
#    'V_8722': False,
#    'V_fax': False,
#    'V_1': False,
#    'V_doc': False,
#    'V_opm': False,
#    'V_hours': False,
#    'V_survey': False,
#    'V_january': False,
#    'V_reminder': False,
#    'V_friendly': False,
#    'V_today': False,
#    'V_those': False,
#    'V_who': False,
#    'V_already': False,
#    'V_completed': False,
#    'V_disregard': False,
#    'V_thanks': False,
#    'V_north': False,
#    'V_corp': False,
#    'V_from': False,
#    'V_suzanne': False,
#    'V_nicholie': False,
#    'V_02': False,
#    'V_01': False,
#    'V_05': False,
#    'V_pm': False,
#    'V_larry': False,
#    'V_joe': False,
#    'V_hunter': False,
#    'V_hou': False,
#    'V_ect': False,
#    'V_mark': False,
#    'V_thorne': False,
#    'V_linda': False,
#    'V_bryan': False,
#    'V_mary': False,
#    'V_g': False,
#    'V_gosnell': False,
#    'V_bill': False,
#    'V_hare': False,
#    'V_avril': False,
#    'V_forster': False,
#    'V_kelly': False,
#    'V_lombardi': False,
#    'V_na': False,
#    'V_diane': False,
#    'V_h': False,
#    'V_cook': False,
#    'V_david': False,
#    'V_maxwell': False,
#    'V_rebecca': False,
#    'V_darron': False,
#    'V_c': False,
#    'V_giron': False,
#    'V_kam': False,
#    'V_keiser': False,
#    'V_william': False,
#    'V_john': False,
#    'V_valdes': False,
#    'V_melissa': False,
#    'V_k': False,
#    'V_ratnala': False,
#    'V_errol': False,
#    'V_mclaughlin': False,
#    'V_katherine': False,
#    'V_l': False,
#    'V_stacey': False,
#    'V_w': False,
#    'V_white': False,
#    'V_thresa': False,
#    'V_allen': False,
#    'V_howard': False,
#    'V_b': False,
#    'V_camp': False,
#    'V_kristen': False,
#    'V_j': False,
#    'V_hanson': False,
#    'V_rita': False,
#    'V_wynne': False,
#    'V_daren': False,
#    'V_farmer': False,
#    'V_baumbach': False,
#    'V_irene': False,
#    'V_flynn': False,
#    'V_torrey': False,
#    'V_moorer': False,
#    'V_chris': False,
#    'V_abel': False,
#    'V_cheryl': False,
#    'V_dudley': False,
#    'V_m': False,
#    'V_smith': False,
#    'V_phillip': False,
#    'V_love': False,
#    'V_adrial': False,
#    'V_boals': False,
#    'V_marvia': False,
#    'V_jefferson': False,
#    'V_heather': False,
#    'V_choate': False,
#    'V_irena': False,
#    'V_hogan': False,
#    'V_cc': False,
#    'V_kim': False,
#    'V_theriot': False,
#    'V_carolyn': False,
#    'V_gilley': False,
#    'V_steve': False,
#    'V_venturatos': False,
#    'V_shona': False,
#    'V_wilson': False,
#    'V_edward': False,
#    'V_terry': False,
#    'V_victor': False,
#    'V_lamadrid': False,
#    'V_george': False,
#    'V_randall': False,
#    'V_gay': False,
#    'V_donna': False,
#    'V_greif': False,
#    'V_jeffrey': False,
#    'V_gossett': False,
#    'V_bryce': False,
#    'V_baxter': False,
#    'V_michael': False,
#    'V_eiben': False,
#    'V_sheri': False,
#    'V_thomas': False,
#    'V_james': False,
#    'V_scribner': False,
#    'V_dawn': False,
#    'V_derr': False,
#    'V_shari': False,
#    'V_mao': False,
#    'V_subject': False,
#    'V_changes': False,
#    'V_read': False,
#    "V_'": False,
#    'V_again': False,
#    'V_enter': False,
#    'V_activities': False,
#    'V_shortcut': False,
#    'V_below': False,
#    'V_go': False,
#    'V_path': False,
#    'V_o': False,
#    'V_\\': False,
#    'V__': False,
#    'V_ops': False,
#    'V_produser': False,
#    'V_note': False,
#    'V_there': False,
#    'V_month': False,
#    'V_follows': False,
#    'V_must': False,
#    'V_sap': False,
#    'V_cost': False,
#    'V_center': False,
#    'V_converts': False,
#    'V_old': False,
#    'V_incase': False,
#    'V_don': False,
#    'V_t': False,
#    'V_one': False,
#    'V_2': False,
#    'V_conversion': False,
#    'V_unable': False,
#    'V_roll': False,
#    'V_over': False,
#    'V_previous': False,
#    'V_commercial': False,
#    'V_teams': False,
#    'V_headcount': False,
#    'V_fte': False,
#    'V_information': False,
#    'V_therefore': False,
#    'V_need': False,
#    'V_supports': False,
#    'V_beginning': False,
#    'V_3': False,
#    'V_print': False,
#    'V_report': False,
#    'V_showed': False,
#    'V_prior': False,
#    'V_activity': False,
#    'V_function': False,
#    'V_call': False,
#    'V_me': False,
#    'V_forward': False,
#    'V_when': False,
#    'V_completing': False,
#    'V_section': False,
#    'V_director': False,
#    'V_sr': False,
#    'V_admin': False,
#    'V_positions': False,
#    'V_complete': False,
#    'V_accordingly': False,
#    'V_expected': False,
#    'V_but': False,
#    'V_them': False,
#    'V_included': False,
#    'V_wednesday': False,
#    'V_february': False,
#    'V_help': False,
#    'V_x': False,
#    'V_5': False,
#    'V_7341': False,
#    'V_timeline': False,
#    'V_calendars': False,
#    'V_per': False,
#    'V_management': False,
#    'V_offsite': False,
#    'V_meeting': False,
#    'V_monthly': False,
#    'V_showing': False,
#    'V_vital': False,
#    'V_days': False,
#    'V_close': False,
#    'V_bid': False,
#    'V_week': False,
#    'V_etc': False,
#    'V_necessary': False,
#    'V_capture': False,
#    'V_all': False,
#    'V_assistants': False,
#    'V_accomplished': False,
#    'V_before': False,
#    'V_monday': False,
#    'V_without': False,
#    'V_set': False,
#    'V_sit': False,
#    'V_down': False,
#    'V_handle': False,
#    'V_thank': False,
#    'V_yvette': False,
#    'V_5953': False,
#    'V_capsize': False,
#    'V_looking': False,
#    'V_perfect': False,
#    'V_gift': False,
#    'V_consider': False,
#    'V_*': False,
#    'V_rolex': False,
#    'V_box': False,
#    'V_person': False,
#    'V_everything': False,
#    'V_something': False,
#    'V_truely': False,
#    'V_unique': False,
#    'V_replica': False,
#    'V_sets': False,
#    'V_highest': False,
#    'V_swiss': False,
#    'V_quality': False,
#    'V_been': False,
#    'V_replicated': False,
#    'V_perfectly': False,
#    'V_right': False,
#    'V_serial': False,
#    'V_numbers': False,
#    'V_green': False,
#    'V_sticker': False,
#    'V_authenticity': False,
#    'V_second': False,
#    'V_hand': False,
#    'V_actually': False,
#    'V_sways': False,
#    'V_instead': False,
#    'V_ticking': False,
#    'V_main': False,
#    'V_flaw': False,
#    'V_most': False,
#    'V_existing': False,
#    'V_experts': False,
#    'V_even': False,
#    'V_fooled': False,
#    'V_weight': False,
#    'V_watches': False,
#    'V_tag': False,
#    'V_hueur': False,
#    'V_cartier': False,
#    'V_bvlgari': False,
#    'V_more': False,
#    'V_women': False,
#    'V_mens': False,
#    'V_childrens': False,
#    'V_styles': False,
#    'V_www': False,
#    'V_xantz': False,
#    'V_oragod': False,
#    'V_did': False,
#    'V_reach': False,
#    'V_error': False,
#    'V_z': False,
#    'V_php': False,
#    'V_win': False,
#    'V_turbocharged': False,
#    'V_jaguar': False,
#    'V_xp': False,
#    'V_carter': False,
#    'V_casino': False,
#    'V_affirmation': False,
#    'V_transfer': False,
#    'V_free': False,
#    'V_into': False,
#    'V_account': False,
#    'V_f': False,
#    'V_n': False,
#    'V_y': False,
#    'V_bonus': False,
#    'V_real': False,
#    'V_downloading': False,
#    'V_making': False,
#    'V_first': False,
#    'V_certain': False,
#    'V_conditions': False,
#    'V_apply': False,
#    'V_cheating': False,
#    'V_house': False,
#    'V_wife': False,
#    'V_discount': False,
#    'V_drugs': False,
#    'V_save': False,
#    'V_70': False,
#    'V_%': False,
#    'V_softtabs': False,
#    'V_viagra': False,
#    'V_disolves': False,
#    'V_under': False,
#    'V_tongue': False,
#    'V_simply': False,
#    'V_half': False,
#    'V_pill': False,
#    'V_15': False,
#    'V_min': False,
#    'V_sex': False,
#    'V_excperience': False,
#    'V_super': False,
#    'V_hard': False,
#    'V_erection': False,
#    'V_pleasure': False,
#    'V_greater': False,
#    'V_stamina': False,
#    'V_ship': False,
#    'V_wide': False,
#    'V_prescription': False,
#    'V_required': False,
#    'V_impotent': False,
#    'V_viiagra': False,
#    'V_increase': False,
#    'V_size': False,
#    'V_power': False,
#    'V_loving': False,
#    'V_she': False,
#    'V_deserves': False,
#    'V_cheaper': False,
#    'V_supplier': False,
#    'V_retail': False,
#    'V_price': False,
#    'V_ea': False,
#    'V_=': False,
#    'V_17': False,
#    'V_many': False,
#    'V_other': False,
#    'V_meds': False,
#    'V_onlinegenericshop': False,
#    'V_aa': False,
#    'V_out': False,
#    'V_party': False,
#    'V_pack': False,
#    'V_well': False,
#    'V_confidentiality': False,
#    'V_assured': False,
#    'V_urgent': False,
#    'V_assistance': False,
#    'V_dear': False,
#    'V_friend': False,
#    'V_pray': False,
#    'V_god': False,
#    'V_almight': False,
#    'V_reaches': False,
#    'V_wonderful': False,
#    'V_spirit': False,
#    'V_am': False,
#    'V_mrs': False,
#    'V_jessica': False,
#    'V_savimbi': False,
#    'V_angola': False,
#    'V_got': False,
#    'V_contact': False,
#    'V_profle': False,
#    'V_coupled': False,
#    'V_gathered': False,
#    'V_external': False,
#    'V_trade': False,
#    'V_department': False,
#    'V_my': False,
#    'V_country': False,
#    'V_chamber': False,
#    'V_commerce': False,
#    'V_imformation': False,
#    'V_keep': False,
#    'V_very': False,
#    'V_confidential': False,
#    'V_sum': False,
#    'V_ammount': False,
#    'V_husband': False,
#    'V_unita': False,
#    'V_rebel': False,
#    'V_leader': False,
#    'V_jonas': False,
#    'V_malheiro': False,
#    'V_deposited': False,
#    'V_bank': False,
#    'V_africa': False,
#    'V_suspense': False,
#    'V_safe': False,
#    'V_keeping': False,
#    'V_he': False,
#    'V_was': False,
#    'V_killed': False,
#    'V_angolan': False,
#    'V_millitary': False,
#    'V_force': False,
#    'V_squable': False,
#    'V_happened': False,
#    'V_issue': False,
#    'V_mineral': False,
#    'V_allocation': False,
#    'V_resource': False,
#    'V_diamond': False,
#    'V_using': False,
#    'V_his': False,
#    'V_influence': False,
#    'V_smuggled': False,
#    'V_neighbouring': False,
#    'V_exchanged': False,
#    'V_valuable': False,
#    'V_asset': False,
#    'V_married': False,
#    'V_three': False,
#    'V_wives': False,
#    'V_led': False,
#    'V_urgly': False,
#    'V_incidents': False,
#    'V_presently': False,
#    'V_staying': False,
#    'V_cotonou': False,
#    'V_life': False,
#    'V_children': False,
#    'V_10': False,
#    'V_500': False,
#    'V_000': False,
#    'V_00': False,
#    'V_dollars': False,
#    'V_assits': False,
#    'V_fund': False,
#    'V_advise': False,
#    'V_shall': False,
#    'V_open': False,
#    'V_small': False,
#    'V_name': False,
#    'V_through': False,
#    'V_20': False,
#    'V_assitance': False,
#    'V_risk': False,
#    'V_transaction': False,
#    'V_remain': False,
#    'V_balance': False,
#    'V_investiment': False,
#    'V_intrested': False,
#    'V_maintain': False,
#    'V_mail': False,
#    'V_immediately': False,
#    'V_clearification': False,
#    'V_refugees': False,
#    'V_nigeria': False,
#    'V_becuase': False,
#    'V_killing': False,
#    'V_civil': False,
#    'V_war': False,
#    'V_going': False,
#    'V_kindly': False,
#    'V_kc': False,
#    'V_2005': False,
#    'V_8': False,
#    'V_speak': False,
#    'V_english': False,
#    'V_send': False,
#    'V_loved': False,
#    'V_ones': False,
#    'V_easter': False,
#    'V_eggs': False,
#    'V_figolli': False,
#    'V_shop': False,
#    'V_online': False,
#    'V_di': False,
#    'V_found': False,
#    'V_school': False,
#    'V_coffee': False,
#    'V_maker': False,
#    'V_gevalia': False,
#    'V_unsubscribe': False,
#    'V_receiving': False,
#    'V_opt': False,
#    'V_requests': False,
#    'V_1102': False,
#    'V_third': False,
#    'V_ave': False,
#    'V_501': False,
#    'V_huntington': False,
#    'V_wv': False,
#    'V_25701': False,
#    'V_received': False,
#    'V_advertisement': False,
#    'V_because': False,
#    'V_registered': False,
#    'V_advertiser': False,
#    'V_website': False,
#    'V_service': False,
#    'V_sent': False,
#    'V_stop': False,
#    'V_advertisements': False,
#    'V_instructions': False,
#    'V_mailing': False,
#    'V_list': False,
#    'V_blank': False,
#    'V_superdealsl': False,
#    'V_392': False,
#    'V_bodf': False,
#    'V_iit': False,
#    'V_demokritos': False,
#    'V_gr': False,
#    'V_paliourg': False,
#    'V_moosq': False,
#    'V_offer': False,
#    'V_optinrealbig': False,
#    'V_llc': False,
#    'V_1333': False,
#    'V_120': False,
#    'V_101': False,
#    'V_westminster': False,
#    'V_co': False,
#    'V_80234': False,
#    'V_fw': False,
#    'V_deal': False,
#    'V_819348': False,
#    'V_fyi': False,
#    'V_original': False,
#    'V_balfour': False,
#    'V_flanagan': False,
#    'V_cyndie': False,
#    'V_thursday': False,
#    'V_june': False,
#    'V_07': False,
#    'V_richardson': False,
#    'V_anderson': False,
#    'V_bridgette': False,
#    'V_campos': False,
#    'V_anthony': False,
#    'V_gonzales': False,
#    'V_sharon': False,
#    'V_hernandez': False,
#    'V_elizabeth': False,
#    'V_deming': False,
#    'V_richard': False,
#    'V_osire': False,
#    'V_ann': False,
#    'V_wallumrod': False,
#    'V_ellen': False,
#    'V_assuming': False,
#    'V_since': False,
#    'V_desk': False,
#    'V_deals': False,
#    'V_negotiated': False,
#    'V_ces': False,
#    'V_counterparties': False,
#    'V_truncated': False,
#    'V_split': False,
#    'V_move': False,
#    'V_production': False,
#    'V_ena': False,
#    'V_im': False,
#    'V_longer': False,
#    'V_exists': False,
#    'V_post': False,
#    'V_aep': False,
#    'V_processes': False,
#    'V_lonestar': False,
#    'V_several': False,
#    'V_times': False,
#    'V_researching': False,
#    'V_midcon': False,
#    'V_incorrectly': False,
#    'V_contract': False,
#    'V_96035432': False,
#    'V_fact': False,
#    'V_gtc': False,
#    'V_firm': False,
#    'V_had': False,
#    'V_ended': False,
#    'V_03': False,
#    'V_31': False,
#    'V_won': False,
#    'V_bother': False,
#    'V_correcting': False,
#    'V_needs': False,
#    'V_moved': False,
#    'V_96061912': False,
#    'V_reviewed': False,
#    'V_cp': False,
#    'V_inactivated': False,
#    'V_could': False,
#    'V_revalidate': False,
#    'V_team': False,
#    'V_add': False,
#    ...},
#   'ham')]

# %%
# training the model using Naive Bayes classifier with a 90/10 split

# Set the seed for reproducibility
random.seed(9)

# Shuffle the data
random.shuffle(featuresets)

# Calculate the split index
split_index = int(len(featuresets) * 0.9)

# Split the data into training and testing sets
train_set = featuresets[:split_index]
test_set = featuresets[split_index:]

# Print the number of samples in each set
print(f'Number of training samples: {len(train_set)}')
print(f'Number of testing samples: {len(test_set)}')

classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy of the classifier
print (f'Classifier Accuracy: {nltk.classify.accuracy(classifier, test_set)}')
# Out:
# Number of training samples: 1800
# Number of testing samples: 200
# Classifier Accuracy: 0.84

# %%
# Make predictions on the test set
test_features = [feat for feat, label in test_set]
true_labels = [label for feat, label in test_set]
predicted_labels = [classifier.classify(feat) for feat in test_features]

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Classification report for more detailed metrics
print("\nClassification Report:")
print(classification_report(true_labels, predicted_labels))
# Out:
# Confusion Matrix:
# [[105   7]
#  [ 25  63]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          ham       0.81      0.94      0.87       112
#         spam       0.90      0.72      0.80        88
#
#     accuracy                           0.84       200
#    macro avg       0.85      0.83      0.83       200
# weighted avg       0.85      0.84      0.84       200

# %%
# show which features of classifier are most informative
print(classifier.show_most_informative_features(20))
# Out:
# Most Informative Features
#              V_forwarded = True              ham : spam   =    157.8 : 1.0
#                    V_ect = True              ham : spam   =    145.5 : 1.0
#                    V_hou = True              ham : spam   =    140.0 : 1.0
#                    V_nom = True              ham : spam   =     90.7 : 1.0
#                    V_bob = True              ham : spam   =     64.0 : 1.0
#                 V_farmer = True              ham : spam   =     63.1 : 1.0
#             V_nomination = True              ham : spam   =     62.0 : 1.0
#                    V_713 = True              ham : spam   =     52.4 : 1.0
#                   V_2001 = True              ham : spam   =     45.5 : 1.0
#              V_microsoft = True             spam : ham    =     41.9 : 1.0
#                  V_susan = True              ham : spam   =     38.7 : 1.0
#                      V_| = True             spam : ham    =     38.6 : 1.0
#                     V_cc = True              ham : spam   =     38.2 : 1.0
#           V_prescription = True             spam : ham    =     34.1 : 1.0
#                    V_ami = True              ham : spam   =     33.9 : 1.0
#                   V_2005 = True             spam : ham    =     33.4 : 1.0
#                   V_size = True             spam : ham    =     33.4 : 1.0
#                   V_lisa = True              ham : spam   =     33.2 : 1.0
#                    V_act = True             spam : ham    =     32.8 : 1.0
#                 V_taylor = True              ham : spam   =     31.2 : 1.0
# None

# %% [markdown]
# #### Overall, using all of the words as word features was relatively successful. An 84% accuracy is relatively good, but there is still much room for improvement.

# %% [markdown]
# # Experiment 2: Bag of Words Features - Filtered
# ### Same as experiment 1, but no stopwords and only use the 2000 most common words

# %%
# We will first start with bag of words feature sets
# The most common words will become email features
just_words = [word for words,label in emaildocs for word in words]

# %%
# removing stopwords
nltkstopwords = nltk.corpus.stopwords.words('english')
# These words/symbols were very common in later steps so they were removed
mystopwords = ['-','.',',','/',':','(',')']

stopwords = nltkstopwords + mystopwords

stopped_words = [w for w in just_words if not w in stopwords]
len(stopped_words)
# Out:
# 258245

# %%
# use words from all emails to define the word vector for features
# words are also put into a frequency distribution
all_words = nltk.FreqDist(w.lower() for w in stopped_words)
print(len(all_words))
# Out:
# 34576

# %%
# get the 2000 most frequently appearing keywords in the corpus
word_items = all_words.most_common(2000)
word_features = [word for (word, freq) in word_items]
# show the some of the most common words
print(word_features[:100])
# Out:
# ['ect', '@', 'subject', '?', '=', "'", '!', 'hou', 'enron', ';', '$', '_', '2000', 'com', '3', '>', '``', 'please', '1', '|', '00', '2', 'gas', '*', '%', '#', 'deal', '0', 'http', '10', '000', 'e', 'pm', 'meter', 'cc', '5', 'hpl', '4', 'new', '2001', 'company', 'price', 'may', 'get', '01', '7', 'information', 'thanks', 'daren', 'corp', '11', 'need', '&', 'know', 'email', 'us', 'www', 'time', '12', '6', 'font', '9', 'see', 'one', 'message', 'td', '8', 'l', 'j', 'mmbtu', 'p', 'forwarded', 'nbsp', '99', 'would', '15', '20', 'let', '30', 'statements', '03', 'height', 'day', 'attached', 'farmer', 'c', 'th', 'x', 'also', '+', '02', 'b', '100', 'mail', 'xls', '25', '09', '[', ']', 'like']

# %%
# same function as above
def email_features(email, word_features):
	email_words = set(email)
	features = {}
	for word in word_features:
		features['V_%s' % word] = (word in email_words)
	return features

# %%
# get features sets for a document, including keyword features and category feature
featuresets = [(email_features(d, word_features), c) for (d,c) in emaildocs]

# %%
# training the model using Naive Bayes classifier with a 90/10 split

# Set the seed for reproducibility
random.seed(9)

# Shuffle the data
random.shuffle(featuresets)

# Calculate the split index
split_index = int(len(featuresets) * 0.9)

# Split the data into training and testing sets
train_set = featuresets[:split_index]
test_set = featuresets[split_index:]

# Print the number of samples in each set
print(f'Number of training samples: {len(train_set)}')
print(f'Number of testing samples: {len(test_set)}')

classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy of the classifier
print (f'Classifier Accuracy: {nltk.classify.accuracy(classifier, test_set)}')
# Out:
# Number of training samples: 1800
# Number of testing samples: 200
# Classifier Accuracy: 0.925

# %%
# Make predictions on the test set
test_features = [feat for feat, label in test_set]
true_labels = [label for feat, label in test_set]
predicted_labels = [classifier.classify(feat) for feat in test_features]

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Classification report for more detailed metrics
print("\nClassification Report:")
print(classification_report(true_labels, predicted_labels))
# Out:
# Confusion Matrix:
# [[101  11]
#  [  4  84]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          ham       0.96      0.90      0.93       112
#         spam       0.88      0.95      0.92        88
#
#     accuracy                           0.93       200
#    macro avg       0.92      0.93      0.92       200
# weighted avg       0.93      0.93      0.93       200

# %% [markdown]
# #### This second experiment had much better results than the first. By removing stopwords and narrowing the number of feature words, the accuracy jumped to 94%

# %% [markdown]
# # Experiment 3: Cross-Validation
# ### Using the results of experiment 2, the following code performs cross validation as well

# %%
## cross-validation ##
# this function takes the number of folds, the feature sets and it iterates over the folds.
# It prints the accuracy for each fold and the average accuracy at the end.

def cross_validation_accuracy(num_folds, featuresets):
    subset_size = int(len(featuresets)/num_folds)
    print('Each fold size:', subset_size)
    accuracy_list = []
    # iterate over the folds
    for i in range(num_folds):
        test_this_round = featuresets[(i*subset_size):][:subset_size]
        train_this_round = featuresets[:(i*subset_size)] + featuresets[((i+1)*subset_size):]
        # train using train_this_round
        classifier = nltk.NaiveBayesClassifier.train(train_this_round)
        # evaluate against test_this_round and save accuracy
        accuracy_this_round = nltk.classify.accuracy(classifier, test_this_round)
        print (i, accuracy_this_round)
        accuracy_list.append(accuracy_this_round)
    # find mean accuracy over all rounds
    print ('mean accuracy', sum(accuracy_list) / num_folds)

# %%
# Here we use cross validation to do the same training as above
num_folds = 4
cross_validation_accuracy(num_folds, featuresets)
# Out:
# Each fold size: 500
# 0 0.956
# 1 0.946
# 2 0.952
# 3 0.924
# mean accuracy 0.9445

# %% [markdown]
# #### For the cross-validation, the best results were found by choosing between 3-7 folds. For this experiment, 4 folds yielded the best results. This shows a slight improvement over the results of experiment 2.

# %% [markdown]
# # Experiment 4: Bag of Words Features with Less Words
#
# ### This is the same as experiment 2, but this time with only 1000 words

# %%
# We will first start with bag of words feature sets
# The most common words will become email features
just_words = [word for words,label in emaildocs for word in words]

# %%
# removing stopwords
nltkstopwords = nltk.corpus.stopwords.words('english')
# These words/symbols were very common in later steps so they were removed
mystopwords = ['-','.',',','/',':','(',')']
stopwords = nltkstopwords + mystopwords

stopped_words = [w for w in just_words if not w in stopwords]

# %%
# use words from all emails to define the word vector for features
# words are also put into a frequency distribution
all_words = nltk.FreqDist(w.lower() for w in stopped_words)

# %%
# get the 1000 most frequently appearing keywords in the corpus
word_items = all_words.most_common(1000)
word_features = [word for (word, freq) in word_items]
print(word_features[:100])
# Out:
# ['ect', '@', 'subject', '?', '=', "'", '!', 'hou', 'enron', ';', '$', '_', '2000', 'com', '3', '>', '``', 'please', '1', '|', '00', '2', 'gas', '*', '%', '#', 'deal', '0', 'http', '10', '000', 'e', 'pm', 'meter', 'cc', '5', 'hpl', '4', 'new', '2001', 'company', 'price', 'may', 'get', '01', '7', 'information', 'thanks', 'daren', 'corp', '11', 'need', '&', 'know', 'email', 'us', 'www', 'time', '12', '6', 'font', '9', 'see', 'one', 'message', 'td', '8', 'l', 'j', 'mmbtu', 'p', 'forwarded', 'nbsp', '99', 'would', '15', '20', 'let', '30', 'statements', '03', 'height', 'day', 'attached', 'farmer', 'c', 'th', 'x', 'also', '+', '02', 'b', '100', 'mail', 'xls', '25', '09', '[', ']', 'like']

# %%
# same as before
def email_features(email, word_features):
	email_words = set(email)
	features = {}
	for word in word_features:
		features['V_%s' % word] = (word in email_words)
	return features

# %%
# get features sets for a document, including keyword features and category feature
featuresets = [(email_features(d, word_features), c) for (d,c) in emaildocs]

# %%
# training the model using Naive Bayes classifier with a 90/10 split

# Set the seed for reproducibility
random.seed(9)

# Shuffle the data
random.shuffle(featuresets)

# Calculate the split index
split_index = int(len(featuresets) * 0.9)

# Split the data into training and testing sets
train_set = featuresets[:split_index]
test_set = featuresets[split_index:]

# Print the number of samples in each set
print(f'Number of training samples: {len(train_set)}')
print(f'Number of testing samples: {len(test_set)}')

classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy of the classifier
print (f'Classifier Accuracy: {nltk.classify.accuracy(classifier, test_set)}')
# Out:
# Number of training samples: 1800
# Number of testing samples: 200
# Classifier Accuracy: 0.93

# %%
# Make predictions on the test set
test_features = [feat for feat, label in test_set]
true_labels = [label for feat, label in test_set]
predicted_labels = [classifier.classify(feat) for feat in test_features]

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Optionally, print the classification report for more detailed metrics
print("\nClassification Report:")
print(classification_report(true_labels, predicted_labels))
# Out:
# Confusion Matrix:
# [[98 14]
#  [ 0 88]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          ham       1.00      0.88      0.93       112
#         spam       0.86      1.00      0.93        88
#
#     accuracy                           0.93       200
#    macro avg       0.93      0.94      0.93       200
# weighted avg       0.94      0.93      0.93       200

# %% [markdown]
# #### This was the most effective model so far, with 96% accuracy

# %% [markdown]
# # Experiment 5: POS Tags as Features

# %%
# This function will take data structured like emaildocs and assign POS tags
def POStag_words(data):
    tagged_data = []
    for words, label in data:
        tagged_words = nltk.pos_tag(words)
        tagged_data.append((tagged_words, label))
    return tagged_data

# %%
# define features for the "i"th word in the sentence, including three types of suffix and one pre-word
# the pos features function takes the sentence of untagged words and the index of a word i
#   it creates features for word i, including the previous word i-1
def word_features(sentence, i):    
    features = {"suffix(1)": sentence[i][-1:],
		    "suffix(2)": sentence[i][-2:],
		    "suffix(3)": sentence[i][-3:]}
    
    # this adds a feature for the previous word
    if i == 0:
        features["prev-word"] = "<START>"
    else:
        features["prev-word"] = sentence[i-1]
    
    # this adds a feature for the next word
    if i == len(sentence)-1:
        features["next-word"] = "<END>"
    else:
        features["next-word"] = sentence[i+1]
    
    return features

# %%
# adding parts of speech tags to each word in each email
tagged_emails = POStag_words(emaildocs)
tagged_emails[:1]
# Out:
# [([('Subject', 'NN'),
#    (':', ':'),
#    ('a', 'DT'),
#    ('computer', 'NN'),
#    ('and', 'CC'),
#    ('internet', 'JJ'),
#    ('connection', 'NN'),
#    ('for', 'IN'),
#    ('you', 'PRP'),
#    ('and', 'CC'),
#    ('your', 'PRP$'),
#    ('family', 'NN'),
#    ('as', 'IN'),
#    ('you', 'PRP'),
#    ('know', 'VBP'),
#    (',', ','),
#    ('technology', 'NN'),
#    ('is', 'VBZ'),
#    ('critical', 'JJ'),
#    ('to', 'TO'),
#    ('enron', 'VB'),
#    (';', ':'),
#    ('it', 'PRP'),
#    ('drives', 'VBZ'),
#    ('our', 'PRP$'),
#    ('success', 'NN'),
#    ('and', 'CC'),
#    ('will', 'MD'),
#    ('continue', 'VB'),
#    ('to', 'TO'),
#    ('do', 'VB'),
#    ('so', 'RB'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('future', 'NN'),
#    ('.', '.'),
#    ('technology', 'NN'),
#    ('has', 'VBZ'),
#    ('helped', 'VBN'),
#    ('enron', 'VB'),
#    ('create', 'JJ'),
#    ('new', 'JJ'),
#    ('businesses', 'NNS'),
#    ('like', 'IN'),
#    ('enron', 'NN'),
#    ('broadband', 'NN'),
#    ('services', 'NNS'),
#    ('and', 'CC'),
#    ('enron', 'JJ'),
#    ('net', 'NN'),
#    ('works', 'NNS'),
#    (',', ','),
#    ('and', 'CC'),
#    ('it', 'PRP'),
#    ('is', 'VBZ'),
#    ('responsible', 'JJ'),
#    ('for', 'IN'),
#    ('applications', 'NNS'),
#    ('such', 'JJ'),
#    ('as', 'IN'),
#    ('enrononline', 'NN'),
#    ('and', 'CC'),
#    ('enroncredit', 'NN'),
#    ('.', '.'),
#    ('com', 'NN'),
#    ('.', '.'),
#    ('you', 'PRP'),
#    ('\x01', 'VBP'),
#    (',', ','),
#    ('ve', 'FW'),
#    ('seen', 'VBN'),
#    ('what', 'WP'),
#    ('technology', 'NN'),
#    ('can', 'MD'),
#    ('do', 'VB'),
#    ('at', 'IN'),
#    ('work', 'NN'),
#    ('.', '.'),
#    ('now', 'RB'),
#    ('we', 'PRP'),
#    ('want', 'VBP'),
#    ('you', 'PRP'),
#    ('and', 'CC'),
#    ('your', 'PRP$'),
#    ('family', 'NN'),
#    ('to', 'TO'),
#    ('realize', 'VB'),
#    ('its', 'PRP$'),
#    ('benefits', 'NNS'),
#    ('at', 'IN'),
#    ('home', 'NN'),
#    ('.', '.'),
#    ('with', 'IN'),
#    ('that', 'DT'),
#    ('in', 'IN'),
#    ('mind', 'NN'),
#    (',', ','),
#    ('we', 'PRP'),
#    ('are', 'VBP'),
#    ('excited', 'VBN'),
#    ('to', 'TO'),
#    ('let', 'VB'),
#    ('you', 'PRP'),
#    ('know', 'VB'),
#    ('that', 'IN'),
#    ('we', 'PRP'),
#    ('are', 'VBP'),
#    ('introducing', 'VBG'),
#    ('the', 'DT'),
#    ('clickathome', 'NN'),
#    ('program', 'NN'),
#    (',', ','),
#    ('which', 'WDT'),
#    ('will', 'MD'),
#    ('give', 'VB'),
#    ('each', 'DT'),
#    ('employee', 'NN'),
#    ('a', 'DT'),
#    ('computer', 'NN'),
#    ('for', 'IN'),
#    ('use', 'NN'),
#    ('at', 'IN'),
#    ('home', 'NN'),
#    ('.', '.'),
#    ('where', 'WRB'),
#    ('technology', 'NN'),
#    ('permits', 'VBZ'),
#    (',', ','),
#    ('we', 'PRP'),
#    ('will', 'MD'),
#    ('also', 'RB'),
#    ('subsidize', 'VB'),
#    ('an', 'DT'),
#    ('internet', 'JJ'),
#    ('connection', 'NN'),
#    ('.', '.'),
#    ('with', 'IN'),
#    ('the', 'DT'),
#    ('click', 'NN'),
#    ('of', 'IN'),
#    ('a', 'DT'),
#    ('mouse', 'NN'),
#    (',', ','),
#    ('a', 'DT'),
#    ('home', 'NN'),
#    ('computer', 'NN'),
#    ('plus', 'CC'),
#    ('internet', 'JJ'),
#    ('access', 'NN'),
#    ('will', 'MD'),
#    ('put', 'VB'),
#    ('a', 'DT'),
#    ('world', 'NN'),
#    ('of', 'IN'),
#    ('internet', 'NN'),
#    ('knowledge', 'NN'),
#    ('at', 'IN'),
#    ('your', 'PRP$'),
#    ('family', 'NN'),
#    ('\x01', 'NN'),
#    (',', ','),
#    ('s', 'JJ'),
#    ('fingertips', 'NNS'),
#    ('.', '.'),
#    ('we', 'PRP'),
#    ('have', 'VBP'),
#    ('just', 'RB'),
#    ('signed', 'VBN'),
#    ('an', 'DT'),
#    ('agreement', 'NN'),
#    ('with', 'IN'),
#    ('dell', 'NN'),
#    ('computer', 'NN'),
#    ('corporation', 'NN'),
#    ('to', 'TO'),
#    ('provide', 'VB'),
#    ('the', 'DT'),
#    ('computer', 'NN'),
#    ('hardware', 'NN'),
#    ('.', '.'),
#    ('we', 'PRP'),
#    ('wanted', 'VBD'),
#    ('to', 'TO'),
#    ('let', 'VB'),
#    ('you', 'PRP'),
#    ('know', 'VB'),
#    ('about', 'IN'),
#    ('the', 'DT'),
#    ('program', 'NN'),
#    ('now', 'RB'),
#    ('in', 'IN'),
#    ('case', 'NN'),
#    ('you', 'PRP'),
#    ('and', 'CC'),
#    ('your', 'PRP$'),
#    ('family', 'NN'),
#    ('were', 'VBD'),
#    ('considering', 'VBG'),
#    ('the', 'DT'),
#    ('purchase', 'NN'),
#    ('or', 'CC'),
#    ('upgrade', 'NN'),
#    ('of', 'IN'),
#    ('a', 'DT'),
#    ('home', 'NN'),
#    ('computer', 'NN'),
#    ('or', 'CC'),
#    ('internet', 'JJ'),
#    ('connection', 'NN'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('next', 'JJ'),
#    ('few', 'JJ'),
#    ('months', 'NNS'),
#    ('.', '.'),
#    ('the', 'DT'),
#    ('scope', 'NN'),
#    ('of', 'IN'),
#    ('clickathome', 'NN'),
#    ('includes', 'VBZ'),
#    ('the', 'DT'),
#    ('following', 'NN'),
#    (':', ':'),
#    ('?', '.'),
#    ('basic', 'JJ'),
#    ('package', 'NN'),
#    (':', ':'),
#    ('dell', 'NN'),
#    ('desktop', 'VBZ'),
#    ('computer', 'NN'),
#    ('with', 'IN'),
#    ('a', 'DT'),
#    ('high', 'JJ'),
#    ('-', ':'),
#    ('speed', 'NN'),
#    ('processor', 'NN'),
#    (',', ','),
#    ('floppy', 'JJ'),
#    ('disk', 'NN'),
#    ('drive', 'NN'),
#    (',', ','),
#    ('mouse', 'NN'),
#    (',', ','),
#    ('speakers', 'NNS'),
#    (',', ','),
#    ('monitor', 'NN'),
#    (',', ','),
#    ('modem', 'NN'),
#    (',', ','),
#    ('cd', 'NN'),
#    ('-', ':'),
#    ('rom', 'NN'),
#    ('drive', 'NN'),
#    ('and', 'CC'),
#    ('windows', 'VBZ'),
#    ('2000', 'CD'),
#    ('software', 'NN'),
#    ('.', '.'),
#    ('employees', 'NNS'),
#    ('will', 'MD'),
#    ('have', 'VB'),
#    ('the', 'DT'),
#    ('option', 'NN'),
#    ('to', 'TO'),
#    ('receive', 'VB'),
#    ('a', 'DT'),
#    ('subsidized', 'JJ'),
#    ('internet', 'NN'),
#    ('connection', 'NN'),
#    (',', ','),
#    ('including', 'VBG'),
#    ('broadband', 'NN'),
#    (',', ','),
#    ('where', 'WRB'),
#    ('commercially', 'RB'),
#    ('available', 'JJ'),
#    ('.', '.'),
#    ('?', '.'),
#    ('participation', 'NN'),
#    (':', ':'),
#    ('this', 'DT'),
#    ('program', 'NN'),
#    ('will', 'MD'),
#    ('be', 'VB'),
#    ('available', 'JJ'),
#    ('to', 'TO'),
#    ('active', 'JJ'),
#    ('regular', 'JJ'),
#    ('full', 'JJ'),
#    ('-', ':'),
#    ('time', 'NN'),
#    ('and', 'CC'),
#    ('regular', 'JJ'),
#    ('part', 'NN'),
#    ('-', ':'),
#    ('time', 'NN'),
#    ('employees', 'NNS'),
#    ('of', 'IN'),
#    ('enron', 'NN'),
#    ('and', 'CC'),
#    ('its', 'PRP$'),
#    ('wholly', 'RB'),
#    ('owned', 'VBN'),
#    ('subsidiaries', 'NNS'),
#    (';', ':'),
#    ('however', 'RB'),
#    (',', ','),
#    ('employees', 'NNS'),
#    ('of', 'IN'),
#    ('some', 'DT'),
#    ('enron', 'NN'),
#    ('companies', 'NNS'),
#    ('(', '('),
#    ('portland', 'VB'),
#    ('general', 'JJ'),
#    ('electric', 'JJ'),
#    (',', ','),
#    ('eott', 'NN'),
#    (',', ','),
#    ('enron', 'VBP'),
#    ('facility', 'NN'),
#    ('services', 'NNS'),
#    (')', ')'),
#    ('may', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('able', 'JJ'),
#    ('to', 'TO'),
#    ('participate', 'VB'),
#    ('due', 'JJ'),
#    ('to', 'TO'),
#    ('legal', 'JJ'),
#    (',', ','),
#    ('accounting', 'NN'),
#    (',', ','),
#    ('tax', 'NN'),
#    (',', ','),
#    ('labor', 'NN'),
#    ('or', 'CC'),
#    ('business', 'NN'),
#    ('reasons', 'NNS'),
#    ('.', '.'),
#    ('eligibility', 'NN'),
#    ('includes', 'VBZ'),
#    ('being', 'VBG'),
#    ('employed', 'VBN'),
#    ('at', 'IN'),
#    ('the', 'DT'),
#    ('time', 'NN'),
#    ('of', 'IN'),
#    ('implementation', 'NN'),
#    ('.', '.'),
#    ('?', '.'),
#    ('timing', 'NN'),
#    (':', ':'),
#    ('u', 'NN'),
#    ('.', '.'),
#    ('s', 'NN'),
#    ('.', '.'),
#    ('employee', 'NN'),
#    ('sign', 'NN'),
#    ('-', ':'),
#    ('up', 'RB'),
#    ('will', 'MD'),
#    ('begin', 'VB'),
#    ('in', 'IN'),
#    ('early', 'JJ'),
#    ('2001', 'CD'),
#    (',', ','),
#    ('with', 'IN'),
#    ('delivery', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('equipment', 'NN'),
#    ('and', 'CC'),
#    ('internet', 'NN'),
#    ('connection', 'NN'),
#    ('to', 'TO'),
#    ('follow', 'VB'),
#    ('shortly', 'RB'),
#    ('thereafter', 'RB'),
#    ('.', '.'),
#    ('delivery', 'NN'),
#    ('of', 'IN'),
#    ('equipment', 'NN'),
#    ('to', 'TO'),
#    ('participating', 'VBG'),
#    ('non', 'JJ'),
#    ('-', ':'),
#    ('u', 'NN'),
#    ('.', '.'),
#    ('s', 'NN'),
#    ('.', '.'),
#    ('employees', 'NNS'),
#    ('is', 'VBZ'),
#    ('targeted', 'VBN'),
#    ('for', 'IN'),
#    ('late', 'JJ'),
#    ('2001', 'CD'),
#    ('.', '.'),
#    ('details', 'NNS'),
#    ('about', 'IN'),
#    ('this', 'DT'),
#    ('program', 'NN'),
#    ('are', 'VBP'),
#    ('still', 'RB'),
#    ('being', 'VBG'),
#    ('finalized', 'VBN'),
#    ('.', '.'),
#    ('to', 'TO'),
#    ('address', 'VB'),
#    ('some', 'DT'),
#    ('of', 'IN'),
#    ('your', 'PRP$'),
#    ('initial', 'JJ'),
#    ('questions', 'NNS'),
#    (',', ','),
#    ('we', 'PRP'),
#    ('\x01', 'VBP'),
#    (',', ','),
#    ('ve', 'RB'),
#    ('posted', 'VBD'),
#    ('a', 'DT'),
#    ('question', 'NN'),
#    ('-', ':'),
#    ('and', 'CC'),
#    ('-', ':'),
#    ('answer', 'NN'),
#    ('document', 'NN'),
#    ('on', 'IN'),
#    ('http', 'NN'),
#    (':', ':'),
#    ('/', 'JJ'),
#    ('/', 'NNP'),
#    ('clickathome', 'NN'),
#    ('.', '.'),
#    ('enron', 'NN'),
#    ('.', '.'),
#    ('com', 'NN'),
#    ('.', '.'),
#    ('we', 'PRP'),
#    ('will', 'MD'),
#    ('schedule', 'VB'),
#    ('an', 'DT'),
#    ('espeak', 'NN'),
#    ('session', 'NN'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('near', 'JJ'),
#    ('future', 'NN'),
#    ('where', 'WRB'),
#    ('you', 'PRP'),
#    ('will', 'MD'),
#    ('have', 'VB'),
#    ('an', 'DT'),
#    ('opportunity', 'NN'),
#    ('to', 'TO'),
#    ('ask', 'VB'),
#    ('questions', 'NNS'),
#    ('.', '.'),
#    ('or', 'CC'),
#    (',', ','),
#    ('you', 'PRP'),
#    ('can', 'MD'),
#    ('submit', 'VB'),
#    ('your', 'PRP$'),
#    ('questions', 'NNS'),
#    ('and', 'CC'),
#    ('comments', 'NNS'),
#    ('to', 'TO'),
#    ('clickathome', 'VB'),
#    ('@', 'NNP'),
#    ('enron', 'NN'),
#    ('.', '.'),
#    ('com', 'NN'),
#    ('.', '.'),
#    ('we', 'PRP'),
#    ('are', 'VBP'),
#    ('excited', 'VBN'),
#    ('to', 'TO'),
#    ('extend', 'VB'),
#    ('our', 'PRP$'),
#    ('investment', 'NN'),
#    ('in', 'IN'),
#    ('technology', 'NN'),
#    ('to', 'TO'),
#    ('you', 'PRP'),
#    ('and', 'CC'),
#    ('your', 'PRP$'),
#    ('family', 'NN'),
#    ('.', '.'),
#    ('we', 'PRP'),
#    ('believe', 'VBP'),
#    ('this', 'DT'),
#    ('program', 'NN'),
#    ('takes', 'VBZ'),
#    ('communication', 'NN'),
#    ('at', 'IN'),
#    ('enron', 'NN'),
#    ('to', 'TO'),
#    ('a', 'DT'),
#    ('new', 'JJ'),
#    ('level', 'NN'),
#    ('by', 'IN'),
#    ('creating', 'VBG'),
#    ('endless', 'JJ'),
#    ('possibilities', 'NNS'),
#    ('for', 'IN'),
#    ('you', 'PRP'),
#    ('to', 'TO'),
#    ('experience', 'VB'),
#    ('and', 'CC'),
#    ('participate', 'VB'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('broadband', 'NN'),
#    ('internet', 'NN'),
#    ('revolution', 'NN'),
#    ('.', '.'),
#    ('it', 'PRP'),
#    ('is', 'VBZ'),
#    ('just', 'RB'),
#    ('another', 'DT'),
#    ('reason', 'NN'),
#    ('why', 'WRB'),
#    ('we', 'PRP'),
#    ('believe', 'VBP'),
#    ('enron', 'EX'),
#    ('is', 'VBZ'),
#    ('a', 'DT'),
#    ('great', 'JJ'),
#    ('place', 'NN'),
#    ('to', 'TO'),
#    ('work', 'VB'),
#    ('.', '.')],
#   'ham')]

# %%
featuresets = []

for tagged_email, label in tagged_emails:
    untagged_email = nltk.tag.untag(tagged_email)
    emailfeatures = []

    for i, (word, tag) in enumerate(tagged_email):
        features = word_features(untagged_email, i)
        features["pos_tag"] = tag
        emailfeatures.append(features)
    
    featuresets.append((emailfeatures, label))

# Example usage to display the first 100 featuresets
print(featuresets[0])
# Out:
# ([{'suffix(1)': 't', 'suffix(2)': 'ct', 'suffix(3)': 'ect', 'prev-word': '<START>', 'next-word': ':', 'pos_tag': 'NN'}, {'suffix(1)': ':', 'suffix(2)': ':', 'suffix(3)': ':', 'prev-word': 'Subject', 'next-word': 'a', 'pos_tag': ':'}, {'suffix(1)': 'a', 'suffix(2)': 'a', 'suffix(3)': 'a', 'prev-word': ':', 'next-word': 'computer', 'pos_tag': 'DT'}, {'suffix(1)': 'r', 'suffix(2)': 'er', 'suffix(3)': 'ter', 'prev-word': 'a', 'next-word': 'and', 'pos_tag': 'NN'}, {'suffix(1)': 'd', 'suffix(2)': 'nd', 'suffix(3)': 'and', 'prev-word': 'computer', 'next-word': 'internet', 'pos_tag': 'CC'}, {'suffix(1)': 't', 'suffix(2)': 'et', 'suffix(3)': 'net', 'prev-word': 'and', 'next-word': 'connection', 'pos_tag': 'JJ'}, {'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ion', 'prev-word': 'internet', 'next-word': 'for', 'pos_tag': 'NN'}, {'suffix(1)': 'r', 'suffix(2)': 'or', 'suffix(3)': 'for', 'prev-word': 'connection', 'next-word': 'you', 'pos_tag': 'IN'}, {'suffix(1)': 'u', 'suffix(2)': 'ou', 'suffix(3)': 'you', 'prev-word': 'for', 'next-word': 'and', 'pos_tag': 'PRP'}, {'suffix(1)': 'd', 'suffix(2)': 'nd', 'suffix(3)': 'and', 'prev-word': 'you', 'next-word': 'your', 'pos_tag': 'CC'}, {'suffix(1)': 'r', 'suffix(2)': 'ur', 'suffix(3)': 'our', 'prev-word': 'and', 'next-word': 'family', 'pos_tag': 'PRP$'}, {'suffix(1)': 'y', 'suffix(2)': 'ly', 'suffix(3)': 'ily', 'prev-word': 'your', 'next-word': 'as', 'pos_tag': 'NN'}, {'suffix(1)': 's', 'suffix(2)': 'as', 'suffix(3)': 'as', 'prev-word': 'family', 'next-word': 'you', 'pos_tag': 'IN'}, {'suffix(1)': 'u', 'suffix(2)': 'ou', 'suffix(3)': 'you', 'prev-word': 'as', 'next-word': 'know', 'pos_tag': 'PRP'}, {'suffix(1)': 'w', 'suffix(2)': 'ow', 'suffix(3)': 'now', 'prev-word': 'you', 'next-word': ',', 'pos_tag': 'VBP'}, {'suffix(1)': ',', 'suffix(2)': ',', 'suffix(3)': ',', 'prev-word': 'know', 'next-word': 'technology', 'pos_tag': ','}, {'suffix(1)': 'y', 'suffix(2)': 'gy', 'suffix(3)': 'ogy', 'prev-word': ',', 'next-word': 'is', 'pos_tag': 'NN'}, {'suffix(1)': 's', 'suffix(2)': 'is', 'suffix(3)': 'is', 'prev-word': 'technology', 'next-word': 'critical', 'pos_tag': 'VBZ'}, {'suffix(1)': 'l', 'suffix(2)': 'al', 'suffix(3)': 'cal', 'prev-word': 'is', 'next-word': 'to', 'pos_tag': 'JJ'}, {'suffix(1)': 'o', 'suffix(2)': 'to', 'suffix(3)': 'to', 'prev-word': 'critical', 'next-word': 'enron', 'pos_tag': 'TO'}, {'suffix(1)': 'n', 'suffix(2)': 'on', 'suffix(3)': 'ron', 'prev-word': 'to', 'next-word': ';', 'pos_tag': 'VB'}, {'suffix(1)': ';', 'suffix(2)': ';', 'suffix(3)': ';', 'prev-word': 'enron', 'next-word': 'it', 'pos_tag': ':'}, {'suffix(1)': 't', 'suffix(2)': 'it', 'suffix(3)': 'it', 'prev-word': ';', 'next-word': 'drives', 'pos_tag': 'PRP'}, {'suffix(1)': 's', 'suffix(2)': 'es', 'suffix(3)': 'ves', 'prev-word': 'it', 'next-word': 'our', 'pos_tag': 'VBZ'}, {'suffix(1)': 'r', 'suffix(2)': 'ur', 'suffix(3)': 'our', 'prev-word': 'drives', 'next-word': 'success', 'pos_tag': 'PRP$'}, {'suffix(1)': 's', 'suffix(2)': 'ss', 'suffix(3)': 'ess', 'prev-word': 'our', 'next-word': 'and', 'pos_tag': 'NN'}, {'suffix(1)': 'd', 'suffix(2)': 'nd', 'suffix(3)': 'and', 'prev-word': 'success', 'next-word': 'will', 'pos_tag': 'CC'}, {'suffix(1)': 'l', 'suffix(2)': 'll', 'suffix(3)': 'ill', 'prev-word': 'and', 'next-word': 'continue', 'pos_tag': 'MD'}, {'suffix(1)': 'e', 'suffix(2)': 'ue', 'suffix(3)': 'nue', 'prev-word': 'will', 'next-word': 'to', 'pos_tag': 'VB'}, {'suffix(1)': 'o', 'suffix(2)': 'to', 'suffix(3)': 'to', 'prev-word': 'continue', 'next-word': 'do', 'pos_tag': 'TO'}, {'suffix(1)': 'o', 'suffix(2)': 'do', 'suffix(3)': 'do', 'prev-word': 'to', 'next-word': 'so', 'pos_tag': 'VB'}, {'suffix(1)': 'o', 'suffix(2)': 'so', 'suffix(3)': 'so', 'prev-word': 'do', 'next-word': 'in', 'pos_tag': 'RB'}, {'suffix(1)': 'n', 'suffix(2)': 'in', 'suffix(3)': 'in', 'prev-word': 'so', 'next-word': 'the', 'pos_tag': 'IN'}, {'suffix(1)': 'e', 'suffix(2)': 'he', 'suffix(3)': 'the', 'prev-word': 'in', 'next-word': 'future', 'pos_tag ...

# %%
# using naive Bayesian as classifier
# split data into a training set and a test set, using a 90%/10% split
size = int(len(featuresets) * 0.1)
train_set, test_set = featuresets[size:], featuresets[:size]
print(len(train_set))
print(len(test_set))
# Out:
# 1800
# 200

# %%
# Function to flatten featuresets
def flatten_featuresets(featuresets):
    flattened_featuresets = []
    for email_features, label in featuresets:
        email_feature_dict = {}
        for i, features in enumerate(email_features):
            for key, value in features.items():
                email_feature_dict[f"{key}_{i}"] = value
        flattened_featuresets.append((email_feature_dict, label))
    return flattened_featuresets

# %%
# Flatten the featuresets
flattened_featuresets = flatten_featuresets(featuresets)

# %%
# training the model using Naive Bayes classifier with a 90/10 split

# Set the seed for reproducibility
random.seed(9)

# Shuffle the data
random.shuffle(flattened_featuresets)

# Calculate the split index
split_index = int(len(flattened_featuresets) * 0.9)

# Split the data into training and testing sets
train_set = flattened_featuresets[:split_index]
test_set = flattened_featuresets[split_index:]

# Print the number of samples in each set
print(f'Number of training samples: {len(train_set)}')
print(f'Number of testing samples: {len(test_set)}')

classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy of the classifier
print (f'Classifier Accuracy: {nltk.classify.accuracy(classifier, test_set)}')
# Out:
# Number of training samples: 1800
# Number of testing samples: 200
# Classifier Accuracy: 0.85

# %%
# Make predictions on the test set
test_features = [feat for feat, label in test_set]
true_labels = [label for feat, label in test_set]
predicted_labels = [classifier.classify(feat) for feat in test_features]

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Classification report for more detailed metrics
print("\nClassification Report:")
print(classification_report(true_labels, predicted_labels))
# Out:
# Confusion Matrix:
# [[93 19]
#  [11 77]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          ham       0.89      0.83      0.86       112
#         spam       0.80      0.88      0.84        88
#
#     accuracy                           0.85       200
#    macro avg       0.85      0.85      0.85       200
# weighted avg       0.85      0.85      0.85       200

# %% [markdown]
# #### Using POS tagging proved to be quite effective at detecting spam emails, with 90% accuracy. However, it did not perform as well as the traditional bag of words featuresets.

# %% [markdown]
# # Experiment 6: Word Frequency
#
# ### Instead of using a true/false for each word in the featureset, this model uses the count of each common word as features.

# %%
# collecting all the words in the emails
just_words = [word for words,label in emaildocs for word in words]

# %%
# removing stopwords
nltkstopwords = nltk.corpus.stopwords.words('english')
# These words/symbols were very common in later steps so they were removed
mystopwords = ['-','.',',','/',':','(',')']
stopwords = nltkstopwords + mystopwords

stopped_words = [w for w in just_words if not w in stopwords]

# %%
# use words from all emails to define the word vector for features
# words are also put into a frequency distribution
all_words = nltk.FreqDist(w.lower() for w in stopped_words)

# %%
# Count the frequency of each word in the list
word_counts = Counter(all_words)

# Get the most common 1000 words
common_words = [word for word, _ in word_counts.most_common(1000)]
common_words[:10]
# Out:
# ['ect', '@', 'subject', '?', '=', "'", '!', 'hou', 'enron', ';']

# %%
# This feature function creates features based on the frequency of words, not just boolean
def word_frequency_features(email, word_features):
    features = {}
    for word in word_features:
        features[f'V_{word}'] = email.count(word)
    return features

# %%
# get features sets for a document, including keyword features and category feature
featuresets = [(word_frequency_features(email, common_words), label) for email, label in emaildocs]

# %%
# This shows an example of a featureset for an email
featuresets[2]
# Out:
# ({'V_ect': 0,
#   'V_@': 0,
#   'V_subject': 0,
#   'V_?': 0,
#   'V_=': 0,
#   "V_'": 0,
#   'V_!': 0,
#   'V_hou': 0,
#   'V_enron': 0,
#   'V_;': 0,
#   'V_$': 0,
#   'V__': 0,
#   'V_2000': 1,
#   'V_com': 0,
#   'V_3': 0,
#   'V_>': 0,
#   'V_``': 0,
#   'V_please': 0,
#   'V_1': 0,
#   'V_|': 0,
#   'V_00': 0,
#   'V_2': 0,
#   'V_gas': 0,
#   'V_*': 0,
#   'V_%': 0,
#   'V_#': 0,
#   'V_deal': 0,
#   'V_0': 0,
#   'V_http': 0,
#   'V_10': 0,
#   'V_000': 0,
#   'V_e': 0,
#   'V_pm': 0,
#   'V_meter': 0,
#   'V_cc': 0,
#   'V_5': 0,
#   'V_hpl': 1,
#   'V_4': 0,
#   'V_new': 0,
#   'V_2001': 0,
#   'V_company': 0,
#   'V_price': 0,
#   'V_may': 0,
#   'V_get': 0,
#   'V_01': 0,
#   'V_7': 0,
#   'V_information': 0,
#   'V_thanks': 0,
#   'V_daren': 0,
#   'V_corp': 0,
#   'V_11': 0,
#   'V_need': 0,
#   'V_&': 0,
#   'V_know': 0,
#   'V_email': 0,
#   'V_us': 0,
#   'V_www': 0,
#   'V_time': 0,
#   'V_12': 0,
#   'V_6': 0,
#   'V_font': 0,
#   'V_9': 0,
#   'V_see': 1,
#   'V_one': 0,
#   'V_message': 0,
#   'V_td': 0,
#   'V_8': 0,
#   'V_l': 0,
#   'V_j': 0,
#   'V_mmbtu': 0,
#   'V_p': 0,
#   'V_forwarded': 0,
#   'V_nbsp': 0,
#   'V_99': 0,
#   'V_would': 0,
#   'V_15': 0,
#   'V_20': 0,
#   'V_let': 0,
#   'V_30': 0,
#   'V_statements': 0,
#   'V_03': 0,
#   'V_height': 0,
#   'V_day': 0,
#   'V_attached': 1,
#   'V_farmer': 0,
#   'V_c': 0,
#   'V_th': 0,
#   'V_x': 0,
#   'V_also': 0,
#   'V_+': 0,
#   'V_02': 0,
#   'V_b': 0,
#   'V_100': 0,
#   'V_mail': 0,
#   'V_xls': 2,
#   'V_25': 0,
#   'V_09': 0,
#   'V_[': 0,
#   'V_]': 0,
#   'V_like': 0,
#   'V_r': 0,
#   'V_production': 0,
#   'V_want': 0,
#   'V_report': 0,
#   'V_sent': 0,
#   'V_inc': 0,
#   'V_free': 0,
#   'V_within': 0,
#   'V_05': 0,
#   'V_month': 0,
#   'V_change': 0,
#   'V_energy': 0,
#   'V_pec': 0,
#   'V_width': 0,
#   'V_robert': 0,
#   'V_today': 0,
#   'V_contact': 0,
#   'V_08': 0,
#   'V_business': 0,
#   'V_sitara': 0,
#   'V_forward': 0,
#   'V_deals': 0,
#   'V_call': 0,
#   'V_size': 0,
#   'V_nom': 1,
#   'V_volume': 0,
#   'V_number': 0,
#   'V_04': 0,
#   'V_go': 0,
#   'V_could': 0,
#   'V_first': 0,
#   'V_make': 0,
#   'V_use': 0,
#   'V_click': 0,
#   'V_contract': 0,
#   'V_60': 0,
#   'V_list': 0,
#   'V_money': 0,
#   'V_questions': 0,
#   'V_less': 0,
#   'V_system': 0,
#   'V_texas': 0,
#   'V_50': 0,
#   'V_net': 0,
#   'V_well': 0,
#   'V_06': 0,
#   'V_u': 0,
#   'V_looking': 0,
#   'V_best': 0,
#   'V_07': 0,
#   'V_stock': 0,
#   'V_per': 0,
#   'V_bob': 0,
#   'V_following': 0,
#   'V_days': 0,
#   'V_back': 0,
#   'V_2004': 0,
#   'V_24': 0,
#   'V_order': 0,
#   'V_take': 0,
#   'V_28': 0,
#   'V_file': 1,
#   'V_line': 0,
#   'V_internet': 0,
#   'V_effective': 0,
#   'V_pills': 0,
#   'V_daily': 0,
#   'V_securities': 0,
#   'V_21': 0,
#   'V_products': 0,
#   'V_available': 0,
#   'V_align': 0,
#   'V_volumes': 0,
#   'V_flow': 0,
#   'V_investment': 0,
#   'V_oil': 0,
#   'V_ticket': 0,
#   'V_high': 0,
#   'V_product': 0,
#   'V_95': 0,
#   'V_16': 0,
#   'V_service': 0,
#   'V_713': 0,
#   'V_online': 0,
#   'V_office': 0,
#   'V_save': 0,
#   'V_original': 0,
#   'V_31': 0,
#   'V_v': 0,
#   'V_tr': 0,
#   'V_services': 0,
#   'V_pt': 0,
#   'V_14': 1,
#   'V_n': 0,
#   'V_name': 0,
#   'V_prices': 0,
#   'V_future': 0,
#   'V_nomination': 0,
#   'V_site': 0,
#   'V_sale': 0,
#   'V_due': 0,
#   'V_18': 0,
#   'V_news': 0,
#   'V_march': 0,
#   'V_microsoft': 0,
#   'V_market': 0,
#   'V_said': 0,
#   'V_windows': 0,
#   'V_based': 0,
#   'V_software': 0,
#   'V_ena': 0,
#   'V_address': 0,
#   'V_br': 0,
#   'V_info': 0,
#   'V_border': 0,
#   'V_thank': 0,
#   'V_22': 0,
#   'V_g': 0,
#   'V_17': 0,
#   'V_many': 0,
#   'V_international': 0,
#   'V_45': 0,
#   'V_made': 0,
#   'V_help': 0,
#   'V_send': 0,
#   'V_href': 0,
#   'V_69': 0,
#   'V_center': 0,
#   'V_april': 0,
#   'V_sales': 0,
#   'V_world': 0,
#   'V_mary': 0,
#   'V_account': 0,
#   'V_professional': 0,
#   'V_phone': 0,
#   'V_h': 0,
#   'V_melissa': 0,
#   'V_13': 0,
#   'V_home': 0,
#   'V_vance': 0,
#   'V_purchase': 0,
#   'V_f': 0,
#   'V_plant': 0,
#   'V_two': 0,
#   'V_next': 0,
#   'V_offer': 0,
#   'V_last': 0,
#   'V_23': 0,
#   'V_without': 0,
#   'V_year': 0,
#   'V_nd': 0,
#   'V_million': 0,
#   'V_w': 0,
#   'V_week': 0,
#   'V_work': 0,
#   'V_july': 0,
#   'V_agreement': 0,
#   'V_40': 0,
#   'V_link': 0,
#   'V_face': 0,
#   'V_june': 0,
#   'V_houston': 0,
#   'V_find': 0,
#   'V_90': 0,
#   'V_29': 0,
#   'V_src': 0,
#   'V_26': 0,
#   'V_people': 0,
#   'V_19': 0,
#   'V_family': 0,
#   'V_delivery': 0,
#   "V_''": 0,
#   'V_group': 0,
#   'V_low': 0,
#   'V_hours': 0,
#   'V_k': 0,
#   'V_teco': 0,
#   'V_set': 0,
#   'V_date': 0,
#   'V_computron': 0,
#   'V_needs': 0,
#   'V_gary': 0,
#   'V_look': 0,
#   'V_adobe': 0,
#   'V_susan': 0,
#   'V_reply': 0,
#   'V_smith': 0,
#   'V_request': 0,
#   'V_america': 0,
#   'V_january': 0,
#   'V_co': 0,
#   'V_viagra': 0,
#   'V_total': 0,
#   'V_good': 0,
#   'V_north': 0,
#   'V_27': 0,
#   'V_xp': 0,
#   'V_tap': 0,
#   'V_give': 0,
#   'V_changes': 0,
#   'V_receive': 0,
#   'V_companies': 0,
#   'V_every': 0,
#   'V_style': 0,
#   'V_soft': 0,
#   'V_right': 0,
#   'V_stop': 0,
#   'V_think': 0,
#   'V_special': 0,
#   'V_fax': 0,
#   'V_section': 0,
#   'V_2003': 0,
#   'V_buy': 0,
#   'V_hsc': 0,
#   'V_120': 0,
#   'V_fw': 0,
#   'V_check': 0,
#   'V_ami': 0,
#   'V_color': 0,
#   'V_stocks': 0,
#   'V_visit': 0,
#   'V_part': 0,
#   'V_show': 0,
#   'V_web': 0,
#   'V_cialis': 0,
#   'V_lisa': 0,
#   'V_even': 0,
#   'V_desk': 0,
#   'V_way': 0,
#   'V_trade': 0,
#   'V_act': 0,
#   'V_advice': 0,
#   'V_much': 0,
#   'V_management': 0,
#   'V_security': 0,
#   'V_63': 0,
#   'V_cotten': 0,
#   'V_taylor': 0,
#   'V_top': 0,
#   'V_sure': 0,
#   'V_david': 0,
#   'V_megan': 0,
#   'V_tenaska': 0,
#   'V_html': 0,
#   'V_long': 0,
#   'V_98': 0,
#   'V_provide': 0,
#   'V_keep': 0,
#   'V_80': 0,
#   'V_remove': 0,
#   'V_end': 0,
#   'V_julie': 0,
#   'V_performance': 0,
#   'V_id': 0,
#   'V_hi': 0,
#   'V_great': 0,
#   'V_actuals': 0,
#   'V_currently': 0,
#   'V_via': 0,
#   'V_content': 0,
#   'V_works': 0,
#   'V_george': 0,
#   'V_quality': 0,
#   'V_results': 0,
#   'V_august': 0,
#   'V_still': 0,
#   'V_spot': 0,
#   'V_shares': 0,
#   'V_pay': 0,
#   'V_actual': 0,
#   'V_china': 0,
#   'V_michael': 0,
#   'V_must': 0,
#   'V_161': 0,
#   'V_corporation': 0,
#   'V_december': 0,
#   'V_going': 0,
#   'V_index': 0,
#   'V_44': 0,
#   'V_\x01': 0,
#   'V_place': 0,
#   'V_received': 0,
#   'V_program': 0,
#   'V_increase': 0,
#   'V_friday': 0,
#   'V_rate': 0,
#   'V_process': 0,
#   'V_dollars': 0,
#   'V_current': 0,
#   'V_come': 0,
#   'V_customers': 0,
#   'V_needed': 0,
#   'V_voip': 0,
#   'V_details': 0,
#   'V_believe': 0,
#   'V_500': 0,
#   'V_copy': 0,
#   'V_32': 0,
#   'V_term': 0,
#   'V_using': 0,
#   'V_offers': 0,
#   'V_better': 0,
#   'V_resources': 0,
#   'V_duke': 0,
#   'V_able': 0,
#   'V_mark': 0,
#   'V_read': 0,
#   'V_real': 0,
#   'V_team': 0,
#   'V_`': 0,
#   'V_cd': 0,
#   'V_including': 0,
#   'V_steve': 0,
#   'V_note': 0,
#   'V_iv': 0,
#   'V_september': 0,
#   'V_limited': 0,
#   'V_st': 0,
#   'V_entered': 0,
#   'V_chokshi': 0,
#   'V_brian': 0,
#   'V_ms': 0,
#   'V_full': 0,
#   'V_fee': 0,
#   'V_since': 0,
#   'V_start': 0,
#   'V_control': 0,
#   'V_possible': 0,
#   'V_technology': 0,
#   'V_access': 0,
#   'V_fuel': 0,
#   'V_cost': 0,
#   'V_graves': 0,
#   'V_customer': 0,
#   'V_prior': 0,
#   'V_php': 0,
#   'V_fyi': 0,
#   'V_notice': 0,
#   'V_unify': 0,
#   'V_activity': 0,
#   'V_prescription': 0,
#   'V_paliourg': 0,
#   'V_thursday': 0,
#   'V_problem': 0,
#   'V_point': 0,
#   'V_regards': 0,
#   'V_created': 0,
#   'V_sell': 0,
#   'V_eastrans': 0,
#   'V_tickets': 0,
#   'V_february': 0,
#   'V_got': 0,
#   'V_always': 0,
#   'V_past': 0,
#   'V_pro': 0,
#   'V_trading': 0,
#   'V_feb': 0,
#   'V_revised': 0,
#   'V_used': 0,
#   'V_tom': 0,
#   'V_gif': 0,
#   'V_provided': 0,
#   'V_little': 0,
#   'V_party': 0,
#   'V_fact': 0,
#   'V_oo': 0,
#   'V_include': 0,
#   'V_either': 0,
#   'V_type': 0,
#   'V_jackie': 0,
#   'V_interest': 0,
#   'V_support': 0,
#   'V_another': 0,
#   'V_transport': 0,
#   'V_newsletter': 0,
#   'V_october': 0,
#   'V_investing': 0,
#   'V_bgcolor': 0,
#   'V_suite': 0,
#   'V_issue': 0,
#   'V_paid': 0,
#   'V_manager': 0,
#   'V_review': 0,
#   'V_mobile': 0,
#   'V_meds': 0,
#   'V_pat': 0,
#   'V_years': 0,
#   'V_counterparty': 0,
#   'V_noms': 0,
#   'V_36': 0,
#   'V_months': 0,
#   'V_na': 0,
#   'V_retail': 0,
#   'V_2005': 0,
#   'V_natural': 0,
#   'V_zone': 0,
#   'V_server': 0,
#   'V_wellhead': 0,
#   'V_estimates': 0,
#   'V_data': 0,
#   'V_soon': 0,
#   'V_tu': 0,
#   'V_exchange': 0,
#   'V_middle': 0,
#   'V_computer': 0,
#   'V_continue': 0,
#   'V_create': 0,
#   'V_ces': 0,
#   'V_35': 0,
#   'V_someone': 0,
#   'V_never': 0,
#   'V_easy': 0,
#   'V_global': 0,
#   'V_regarding': 0,
#   'V_young': 0,
#   'V_credit': 0,
#   'V_financial': 0,
#   'V_image': 0,
#   'V_events': 0,
#   'V_put': 0,
#   'V_john': 0,
#   'V_love': 0,
#   'V_life': 0,
#   'V_risk': 0,
#   'V_feel': 0,
#   'V_city': 0,
#   'V_tabs': 0,
#   'V_valign': 0,
#   'V_aimee': 0,
#   'V_moopid': 0,
#   'V_hotlist': 0,
#   'V_second': 0,
#   'V_power': 0,
#   'V_registered': 0,
#   'V_tx': 0,
#   'V_field': 0,
#   'V_img': 0,
#   'V_watch': 0,
#   'V_however': 0,
#   'V_states': 0,
#   'V_move': 0,
#   'V_position': 0,
#   'V_complete': 0,
#   'V_rates': 0,
#   'V_additional': 0,
#   'V_shipping': 0,
#   'V_marketing': 0,
#   'V_pg': 0,
#   'V_tuesday': 0,
#   'V_november': 0,
#   'V_55': 0,
#   'V_dec': 1,
#   'V_three': 0,
#   'V_ls': 0,
#   'V_demand': 0,
#   'V_de': 0,
#   'V_page': 0,
#   'V_man': 0,
#   'V_pefs': 0,
#   'V_technologies': 0,
#   'V_person': 0,
#   'V_wish': 0,
#   'V_mg': 0,
#   'V_worldwide': 0,
#   'V_already': 0,
#   'V_rita': 0,
#   'V_monday': 0,
#   'V_numbers': 0,
#   'V_cash': 0,
#   'V_operating': 0,
#   'V_box': 0,
#   'V_drugs': 0,
#   'V_thru': 0,
#   'V_getting': 0,
#   'V_hplc': 0,
#   'V_anything': 0,
#   'V_jan': 0,
#   'V_meyers': 0,
#   'V_expectations': 0,
#   'V_employees': 0,
#   'V_follow': 0,
#   'V_supply': 0,
#   'V_james': 0,
#   'V_old': 0,
#   'V_required': 0,
#   'V_transaction': 0,
#   'V_website': 0,
#   'V_area': 0,
#   'V_application': 0,
#   'V_done': 0,
#   'V_might': 0,
#   'V_transfer': 0,
#   'V_super': 0,
#   'V_called': 0,
#   'V_action': 0,
#   'V_pipeline': 0,
#   'V_knle': 0,
#   'V_united': 0,
#   'V_48': 0,
#   'V_unsubscribe': 0,
#   'V_firm': 0,
#   'V_cause': 0,
#   'V_pain': 0,
#   'V_risks': 0,
#   'V_colspan': 0,
#   'V_mr': 0,
#   'V_version': 0,
#   'V_industry': 0,
#   'V_wynne': 0,
#   'V_country': 0,
#   'V_nominations': 0,
#   'V_strong': 0,
#   'V_terms': 0,
#   'V_update': 0,
#   'V_try': 0,
#   'V_calls': 0,
#   'V_photoshop': 0,
#   'V_meters': 0,
#   'V_ever': 0,
#   'V_error': 0,
#   'V_development': 0,
#   'V_project': 0,
#   'V_important': 0,
#   'V_39': 0,
#   'V_operations': 0,
#   'V_txu': 0,
#   'V_differ': 0,
#   'V_coastal': 0,
#   'V_removed': 0,
#   'V_enter': 0,
#   'V_utilities': 0,
#   'V_everyone': 0,
#   'V_brand': 0,
#   'V_text': 0,
#   'V_spam': 0,
#   'V_working': 0,
#   'V_hplno': 0,
#   'V_75': 0,
#   'V_images': 0,
#   'V_\\': 0,
#   'V_spreadsheet': 0,
#   'V_major': 0,
#   'V_expect': 0,
#   'V_canada': 0,
#   'V_pricing': 0,
#   'V_charge': 0,
#   'V_payment': 0,
#   'V_release': 0,
#   'V_accounting': 0,
#   'V_70': 0,
#   'V_small': 0,
#   'V_200': 0,
#   'V_deliveries': 0,
#   'V_remember': 0,
#   'V_jones': 0,
#   'V_mx': 0,
#   'V_biz': 0,
#   'V_doc': 0,
#   'V_sex': 0,
#   'V_open': 0,
#   'V_lee': 0,
#   'V_material': 0,
#   'V_private': 0,
#   'V_ready': 0,
#   'V_plans': 0,
#   'V_gcs': 0,
#   'V_cec': 0,
#   'V_contracts': 0,
#   'V_big': 0,
#   'V_amount': 0,
#   'V_wednesday': 0,
#   'V_everything': 0,
#   'V_third': 0,
#   'V_add': 0,
#   'V_iferc': 0,
#   'V_potential': 0,
#   'V_parker': 0,
#   'V_hope': 0,
#   'V_public': 0,
#   'V_confirm': 0,
#   'V_health': 0,
#   'V_away': 0,
#   'V_view': 0,
#   'V_words': 0,
#   'V_jpg': 0,
#   'V_network': 0,
#   'V_donald': 0,
#   'V_form': 0,
#   'V_meet': 0,
#   'V_kind': 0,
#   'V_features': 0,
#   'V_really': 0,
#   'V_state': 0,
#   'V_uncertainties': 0,
#   'V_al': 0,
#   'V_storage': 0,
#   'V_letter': 0,
#   'V_download': 0,
#   'V_something': 0,
#   'V_bank': 0,
#   'V_scheduled': 0,
#   'V_52': 0,
#   'V_around': 0,
#   'V_anyone': 0,
#   'V_things': 0,
#   'V_correct': 0,
#   'V_cf': 0,
#   'V_85': 0,
#   'V_sources': 0,
#   'V_final': 0,
#   'V_case': 0,
#   'V_expected': 0,
#   'V_necessary': 0,
#   'V_certain': 0,
#   'V_clynes': 0,
#   'V_solution': 0,
#   'V_friends': 0,
#   'V_federal': 0,
#   'V_mike': 0,
#   'V_offering': 0,
#   'V_personal': 0,
#   'V_table': 0,
#   'V_users': 0,
#   'V_htmlimg': 0,
#   'V_department': 0,
#   'V_found': 0,
#   'V_im': 0,
#   'V_yet': 0,
#   'V_quick': 0,
#   'V_browser': 0,
#   'V_latest': 0,
#   'V_reinhardt': 0,
#   'V_code': 0,
#   'V_darren': 0,
#   'V_·': 0,
#   'V_wi': 0,
#   'V_~': 0,
#   'V_hplo': 0,
#   'V_124': 0,
#   'V_enronxgate': 0,
#   'V_reason': 0,
#   'V_systems': 0,
#   'V_direct': 0,
#   'V_47': 0,
#   'V_sat': 0,
#   'V_subscribers': 0,
#   'V_epson': 0,
#   'V_issues': 0,
#   'V_loss': 0,
#   'V_sherlyn': 0,
#   'V_music': 0,
#   'V_growth': 0,
#   'V_user': 0,
#   'V_ask': 0,
#   'V_meeting': 0,
#   'V_god': 0,
#   'V_advise': 0,
#   'V_richard': 0,
#   'V_lloyd': 0,
#   'V_valid': 0,
#   'V_taking': 0,
#   'V_weeks': 0,
#   'V_south': 0,
#   'V_involve': 0,
#   'V_vlt': 0,
#   'V_300': 0,
#   'V_interested': 0,
#   'V_albrecht': 0,
#   'V_secure': 0,
#   'V_featured': 0,
#   'V_period': 0,
#   'V_delta': 0,
#   'V_weissman': 0,
#   'V_katherine': 0,
#   'V_safe': 0,
#   'V_zero': 0,
#   'V_body': 0,
#   'V_location': 0,
#   'V_press': 0,
#   'V_weekend': 0,
#   'V_impact': 0,
#   'V_intended': 0,
#   'V_fill': 0,
#   'V_corel': 0,
#   'V_men': 0,
#   'V_54': 0,
#   'V_ltd': 0,
#   'V_generic': 0,
#   'V_cheap': 0,
#   'V_el': 0,
#   'V_card': 0,
#   'V_prize': 0,
#   'V_0310041': 0,
#   'V_late': 0,
#   'V_opportunity': 0,
#   'V_gr': 0,
#   'V_times': 0,
#   'V_katy': 0,
#   'V_sun': 0,
#   'V_large': 0,
#   'V_meaning': 0,
#   'V_given': 0,
#   'V_write': 0,
#   'V_considered': 0,
#   'V_book': 0,
#   'V_pc': 0,
#   'V_medical': 0,
#   'V_morning': 0,
#   'V_revision': 0,
#   'V_travel': 0,
#   'V_aol': 0,
#   'V_projections': 0,
#   'V_producer': 0,
#   'V_hello': 0,
#   'V_macromedia': 0,
#   'V_cds': 0,
#   'V_wanted': 0,
#   'V_begin': 0,
#   'V_calpine': 0,
#   'V_donna': 0,
#   'V_director': 0,
#   'V_discount': 0,
#   'V_express': 0,
#   'V_thought': 0,
#   'V_source': 0,
#   'V_duty': 0,
#   'V_compliance': 0,
#   'V_paste': 0,
#   'V_gathering': 0,
#   'V_left': 0,
#   'V_extended': 0,
#   'V_capital': 0,
#   'V_div': 0,
#   'V_rolex': 0,
#   'V_iit': 0,
#   'V_demokritos': 0,
#   'V_longer': 0,
#   'V_hey': 0,
#   'V_shut': 0,
#   'V_night': 0,
#   'V_recent': 0,
#   'V_readers': 0,
#   'V_portfolio': 0,
#   'V_updated': 0,
#   'V_971': 0,
#   'V_else': 0,
#   'V_aware': 0,
#   'V_approved': 0,
#   'V_factors': 0,
#   'V_publisher': 0,
#   'V_options': 0,
#   'V_edition': 0,
#   'V_0424040': 0,
#   'V_ftar': 0,
#   'V_bring': 0,
#   'V_close': 0,
#   'V_immediately': 0,
#   'V_fast': 0,
#   'V_related': 0,
#   'V_mentioned': 0,
#   'V_59': 0,
#   'V_reports': 0,
#   'V_ic': 0,
#   'V_carlos': 0,
#   'V_42': 0,
#   'V_plan': 0,
#   'V_acton': 0,
#   'V_care': 0,
#   'V_lose': 0,
#   'V_girls': 0,
#   'V_experience': 0,
#   'V_bill': 0,
#   'V_howard': 0,
#   'V_included': 0,
#   'V_perfect': 0,
#   'V_ship': 0,
#   'V_dear': 0,
#   'V_several': 0,
#   'V_agree': 0,
#   'V_investors': 0,
#   'V_play': 0,
#   'V_say': 0,
#   'V_ali': 0,
#   'V_title': 0,
#   'V_clear': 0,
#   'V_lsk': 0,
#   'V_voice': 0,
#   'V_side': 0,
#   'V_sept': 0,
#   'V_problems': 0,
#   'V_56': 0,
#   'V_target': 0,
#   'V_air': 0,
#   'V_logistics': 0,
#   'V_distribution': 0,
#   'V_digital': 0,
#   'V_basin': 0,
#   'V_cut': 0,
#   'V_facility': 0,
#   'V_commercial': 0,
#   'V_hanks': 0,
#   'V_38': 0,
#   'V_reserves': 0,
#   'V_central': 0,
#   'V_nothing': 0,
#   'V_profile': 0,
#   'V_key': 0,
#   'V_rodriguez': 0,
#   'V_6353': 0,
#   'V_neal': 0,
#   'V_thing': 0,
#   'V_orders': 0,
#   'V_others': 0,
#   'V_800': 0,
#   'V_four': 0,
#   'V_run': 0,
#   'V_000000': 0,
#   'V_agent': 0,
#   'V_ability': 0,
#   'V_entex': 0,
#   'V_lannou': 0,
#   'V_49': 0,
#   'V_fixed': 0,
#   'V_normally': 0,
#   'V_publication': 0,
#   'V_physical': 0,
#   'V_drive': 0,
#   'V_schedule': 0,
#   'V_become': 0,
#   'V_swing': 0,
#   'V_different': 0,
#   'V_hot': 0,
#   'V_increased': 0,
#   'V_advantage': 0,
#   'V_tell': 0,
#   'V_requirements': 0,
#   'V_poorman': 0,
#   'V_added': 0,
#   'V_fuels': 0,
#   'V_says': 0,
#   'V_cover': 0,
#   'V_head': 0,
#   'V_projects': 0,
#   'V_basis': 0,
#   'V_items': 0,
#   'V_pharmacy': 0,
#   'V_yahoo': 0,
#   'V_video': 0,
#   'V_claim': 0,
#   'V_short': 0,
#   'V_channel': 0,
#   'V_value': 0,
#   'V_eol': 0,
#   'V_success': 0,
#   'V_camp': 0,
#   'V_baumbach': 0,
#   'V_therefore': 0,
#   'V_hard': 0,
#   'V_lst': 0,
#   'V_addition': 0,
#   'V_rnd': 0,
#   'V_matter': 0,
#   'V_tel': 0,
#   'V_format': 0,
#   'V_taken': 0,
#   'V_beaumont': 0,
#   'V_requested': 0,
#   'V_htm': 0,
#   'V_jennifer': 0,
#   'V_scott': 0,
#   'V_hesse': 0,
#   'V_clem': 0,
#   'V_talk': 0,
#   'V_dy': 0,
#   'V_stack': 0,
#   'V_broadband': 0,
#   'V_plus': 0,
#   'V_includes': 0,
#   'V_legal': 0,
#   'V_survey': 0,
#   'V_victor': 0,
#   'V_etc': 0,
#   'V_handle': 0,
#   'V_weight': 0,
#   'V_making': 0,
#   'V_later': 0,
#   'V_wells': 0,
#   'V_approval': 0,
#   'V_national': 0,
#   'V_alt': 0,
#   'V_usb': 0,
#   'V_priced': 0,
#   'V_confirmation': 0,
#   'V_cotton': 0,
#   'V_track': 0,
#   'V_bridge': 0,
#   'V_bad': 0,
#   'V_methanol': 0,
#   'V_°': 0,
#   'V_savings': 0},
#  'ham')

# %%
# training the model using Naive Bayes classifier with a 90/10 split

# Set the seed for reproducibility
random.seed(9)

# Shuffle the data
random.shuffle(flattened_featuresets)

# Calculate the split index
split_index = int(len(flattened_featuresets) * 0.9)

# Split the data into training and testing sets
train_set = flattened_featuresets[:split_index]
test_set = flattened_featuresets[split_index:]

# Print the number of samples in each set
print(f'Number of training samples: {len(train_set)}')
print(f'Number of testing samples: {len(test_set)}')

classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy of the classifier
print (f'Classifier Accuracy: {nltk.classify.accuracy(classifier, test_set)}')
# Out:
# Number of training samples: 1800
# Number of testing samples: 200
# Classifier Accuracy: 0.865

# %%
# Make predictions on the test set
test_features = [feat for feat, label in test_set]
true_labels = [label for feat, label in test_set]
predicted_labels = [classifier.classify(feat) for feat in test_features]

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Classification report for more detailed metrics
print("\nClassification Report:")
print(classification_report(true_labels, predicted_labels))
# Out:
# Confusion Matrix:
# [[85 17]
#  [10 88]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          ham       0.89      0.83      0.86       102
#         spam       0.84      0.90      0.87        98
#
#     accuracy                           0.86       200
#    macro avg       0.87      0.87      0.86       200
# weighted avg       0.87      0.86      0.86       200

# %% [markdown]
# #### Overall, this was another quite effective model for this task. It was not the highest performer, but did achieve 93% accuracy.

# %% [markdown]
# # Experiment 7: TF-IDF scores (Advanced)

# %%
# Calculate Term Frequency (TF)
def compute_tf(email):
    tf = Counter(email)
    total_words = len(email)
    for word in tf:
        tf[word] = tf[word] / total_words
    return tf

# Calculate Inverse Document Frequency (IDF)
def compute_idf(documents):
    num_docs = len(documents)
    idf = Counter()
    for email in documents:
        unique_words = set(email)
        for word in unique_words:
            idf[word] += 1
    for word in idf:
        idf[word] = math.log(num_docs / idf[word])
    return idf

# Calculate TF-IDF
def compute_tfidf(tf, idf):
    tfidf = {}
    for word, tf_value in tf.items():
        tfidf[word] = tf_value * idf.get(word, 0.0)
    return tfidf

# %%
# Prepare data: list of all emails and list of most common words
all_emails = [email for email, label in emaildocs]
most_common_words_set = set(common_words)

# Calculate IDF for all documents
idf = compute_idf(all_emails)

# %%
# Function to combine frequency and TF-IDF features
def word_frequency_tfidf_features(email, word_features, idf):
    tf = compute_tf(email)
    tfidf = compute_tfidf(tf, idf)
    features = {}
    for word in word_features:
        features[f'V_{word}'] = email.count(word)
        features[f'TFIDF_{word}'] = tfidf.get(word, 0.0)
    return features

# %%
# Final feature sets
featuresets = [(word_frequency_tfidf_features(email, common_words, idf), label) for email, label in emaildocs]

# Output the features for the first email to verify
print(featuresets[2])
# Out:
# ({'V_ect': 0, 'TFIDF_ect': 0.0, 'V_@': 0, 'TFIDF_@': 0.0, 'V_subject': 0, 'TFIDF_subject': 0.0, 'V_?': 0, 'TFIDF_?': 0.0, 'V_=': 0, 'TFIDF_=': 0.0, "V_'": 0, "TFIDF_'": 0.0, 'V_!': 0, 'TFIDF_!': 0.0, 'V_hou': 0, 'TFIDF_hou': 0.0, 'V_enron': 0, 'TFIDF_enron': 0.0, 'V_;': 0, 'TFIDF_;': 0.0, 'V_$': 0, 'TFIDF_$': 0.0, 'V__': 0, 'TFIDF__': 0.0, 'V_2000': 1, 'TFIDF_2000': 0.05975518287199313, 'V_com': 0, 'TFIDF_com': 0.0, 'V_3': 0, 'TFIDF_3': 0.0, 'V_>': 0, 'TFIDF_>': 0.0, 'V_``': 0, 'TFIDF_``': 0.0, 'V_please': 0, 'TFIDF_please': 0.0, 'V_1': 0, 'TFIDF_1': 0.0, 'V_|': 0, 'TFIDF_|': 0.0, 'V_00': 0, 'TFIDF_00': 0.0, 'V_2': 0, 'TFIDF_2': 0.0, 'V_gas': 0, 'TFIDF_gas': 0.0, 'V_*': 0, 'TFIDF_*': 0.0, 'V_%': 0, 'TFIDF_%': 0.0, 'V_#': 0, 'TFIDF_#': 0.0, 'V_deal': 0, 'TFIDF_deal': 0.0, 'V_0': 0, 'TFIDF_0': 0.0, 'V_http': 0, 'TFIDF_http': 0.0, 'V_10': 0, 'TFIDF_10': 0.0, 'V_000': 0, 'TFIDF_000': 0.0, 'V_e': 0, 'TFIDF_e': 0.0, 'V_pm': 0, 'TFIDF_pm': 0.0, 'V_meter': 0, 'TFIDF_meter': 0.0, 'V_cc': 0, 'TFIDF_cc': 0.0, 'V_5': 0, 'TFIDF_5': 0.0, 'V_hpl': 1, 'TFIDF_hpl': 0.07522362731738684, 'V_4': 0, 'TFIDF_4': 0.0, 'V_new': 0, 'TFIDF_new': 0.0, 'V_2001': 0, 'TFIDF_2001': 0.0, 'V_company': 0, 'TFIDF_company': 0.0, 'V_price': 0, 'TFIDF_price': 0.0, 'V_may': 0, 'TFIDF_may': 0.0, 'V_get': 0, 'TFIDF_get': 0.0, 'V_01': 0, 'TFIDF_01': 0.0, 'V_7': 0, 'TFIDF_7': 0.0, 'V_information': 0, 'TFIDF_information': 0.0, 'V_thanks': 0, 'TFIDF_thanks': 0.0, 'V_daren': 0, 'TFIDF_daren': 0.0, 'V_corp': 0, 'TFIDF_corp': 0.0, 'V_11': 0, 'TFIDF_11': 0.0, 'V_need': 0, 'TFIDF_need': 0.0, 'V_&': 0, 'TFIDF_&': 0.0, 'V_know': 0, 'TFIDF_know': 0.0, 'V_email': 0, 'TFIDF_email': 0.0, 'V_us': 0, 'TFIDF_us': 0.0, 'V_www': 0, 'TFIDF_www': 0.0, 'V_time': 0, 'TFIDF_time': 0.0, 'V_12': 0, 'TFIDF_12': 0.0, 'V_6': 0, 'TFIDF_6': 0.0, 'V_font': 0, 'TFIDF_font': 0.0, 'V_9': 0, 'TFIDF_9': 0.0, 'V_see': 1, 'TFIDF_see': 0.07195136336660078, 'V_one': 0, 'TFIDF_one': 0.0, 'V_message': 0, 'TFIDF_message': 0.0, 'V_td': 0, 'TFIDF_td': 0.0, 'V_8': 0, 'TFIDF_8': 0.0, 'V_l': 0, 'TFIDF_l': 0.0, 'V_j': 0, 'TFIDF_j': 0.0, 'V_mmbtu': 0, 'TFIDF_mmbtu': 0.0, 'V_p': 0, 'TFIDF_p': 0.0, 'V_forwarded': 0, 'TFIDF_forwarded': 0.0, 'V_nbsp': 0, 'TFIDF_nbsp': 0.0, 'V_99': 0, 'TFIDF_99': 0.0, 'V_would': 0, 'TFIDF_would': 0.0, 'V_15': 0, 'TFIDF_15': 0.0, 'V_20': 0, 'TFIDF_20': 0.0, 'V_let': 0, 'TFIDF_let': 0.0, 'V_30': 0, 'TFIDF_30': 0.0, 'V_statements': 0, 'TFIDF_statements': 0.0, 'V_03': 0, 'TFIDF_03': 0.0, 'V_height': 0, 'TFIDF_height': 0.0, 'V_day': 0, 'TFIDF_day': 0.0, 'V_attached': 1, 'TFIDF_attached': 0.0836605649165642, 'V_farmer': 0, 'TFIDF_farmer': 0.0, 'V_c': 0, 'TFIDF_c': 0.0, 'V_th': 0, 'TFIDF_th': 0.0, 'V_x': 0, 'TFIDF_x': 0.0, 'V_also': 0, 'TFIDF_also': 0.0, 'V_+': 0, 'TFIDF_+': 0.0, 'V_02': 0, 'TFIDF_02': 0.0, 'V_b': 0, 'TFIDF_b': 0.0, 'V_100': 0, 'TFIDF_100': 0.0, 'V_mail': 0, 'TFIDF_mail': 0.0, 'V_xls': 2, 'TFIDF_xls': 0.21565021448829225, 'V_25': 0, 'TFIDF_25': 0.0, 'V_09': 0, 'TFIDF_09': 0.0, 'V_[': 0, 'TFIDF_[': 0.0, 'V_]': 0, 'TFIDF_]': 0.0, 'V_like': 0, 'TFIDF_like': 0.0, 'V_r': 0, 'TFIDF_r': 0.0, 'V_production': 0, 'TFIDF_production': 0.0, 'V_want': 0, 'TFIDF_want': 0.0, 'V_report': 0, 'TFIDF_report': 0.0, 'V_sent': 0, 'TFIDF_sent': 0.0, 'V_inc': 0, 'TFIDF_inc': 0.0, 'V_free': 0, 'TFIDF_free': 0.0, 'V_within': 0, 'TFIDF_within': 0.0, 'V_05': 0, 'TFIDF_05': 0.0, 'V_month': 0, 'TFIDF_month': 0.0, 'V_change': 0, 'TFIDF_change': 0.0, 'V_energy': 0, 'TFIDF_energy': 0.0, 'V_pec': 0, 'TFIDF_pec': 0.0, 'V_width': 0, 'TFIDF_width': 0.0, 'V_robert': 0, 'TFIDF_robert': 0.0, 'V_today': 0, 'TFIDF_today': 0.0, 'V_contact': 0, 'TFIDF_contact': 0.0, 'V_08': 0, 'TFIDF_08': 0.0, 'V_business': 0, 'TFIDF_business': 0.0, 'V_sitara': 0, 'TFIDF_sitara': 0.0, 'V_forward': 0, 'TFIDF_forward': 0.0, 'V_deals': 0, 'TFIDF_deals': 0.0, 'V_call': 0, 'TFIDF_call': 0.0, 'V_size': 0, 'TFIDF_size': 0.0, 'V_nom': 1, 'TFIDF_nom': 0.10334490490908632, 'V_volume': 0, 'TFIDF_volume': 0.0, 'V_number': 0, 'TFIDF_number': 0.0, 'V_04': ...

# %%
# training the model using Naive Bayes classifier with a 90/10 split

# Set the seed for reproducibility
random.seed(9)

# Shuffle the data
random.shuffle(flattened_featuresets)

# Calculate the split index
split_index = int(len(flattened_featuresets) * 0.9)

# Split the data into training and testing sets
train_set = flattened_featuresets[:split_index]
test_set = flattened_featuresets[split_index:]

# Print the number of samples in each set
print(f'Number of training samples: {len(train_set)}')
print(f'Number of testing samples: {len(test_set)}')

classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy of the classifier
print (f'Classifier Accuracy: {nltk.classify.accuracy(classifier, test_set)}')
# Out:
# Number of training samples: 1800
# Number of testing samples: 200
# Classifier Accuracy: 0.91

# %%
# Make predictions on the test set
test_features = [feat for feat, label in test_set]
true_labels = [label for feat, label in test_set]
predicted_labels = [classifier.classify(feat) for feat in test_features]

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Classification report for more detailed metrics
print("\nClassification Report:")
print(classification_report(true_labels, predicted_labels))
# Out:
# Confusion Matrix:
# [[85 10]
#  [ 8 97]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          ham       0.91      0.89      0.90        95
#         spam       0.91      0.92      0.92       105
#
#     accuracy                           0.91       200
#    macro avg       0.91      0.91      0.91       200
# weighted avg       0.91      0.91      0.91       200

# %% [markdown]
# # Experiment 8: Custom Features - Combining the Best Features
# ### For this experiment, we combine some word features used previously, as well as custom features
# ### Features: Presence of 1000 most common words, Email Length, Average word Length

# %%
# We will first start with bag of words feature sets
# The most common words will become email features
just_words = [word for words,label in emaildocs for word in words]

# %%
# removing stopwords
nltkstopwords = nltk.corpus.stopwords.words('english')
# These words/symbols were very common in later steps so they were removed
mystopwords = ['-','.',',','/',':','(',')']
stopwords = nltkstopwords + mystopwords

stopped_words = [w for w in just_words if not w in stopwords]

# %%
# use words from all emails to define the word vector for features
# words are also put into a frequency distribution
all_words = nltk.FreqDist(w.lower() for w in stopped_words)

# %%
# get the 1000 most frequently appearing keywords in the corpus
word_items = all_words.most_common(1000)
word_features = [word for (word, freq) in word_items]
print(word_features[:100])
# Out:
# ['ect', '@', 'subject', '?', '=', "'", '!', 'hou', 'enron', ';', '$', '_', '2000', 'com', '3', '>', '``', 'please', '1', '|', '00', '2', 'gas', '*', '%', '#', 'deal', '0', 'http', '10', '000', 'e', 'pm', 'meter', 'cc', '5', 'hpl', '4', 'new', '2001', 'company', 'price', 'may', 'get', '01', '7', 'information', 'thanks', 'daren', 'corp', '11', 'need', '&', 'know', 'email', 'us', 'www', 'time', '12', '6', 'font', '9', 'see', 'one', 'message', 'td', '8', 'l', 'j', 'mmbtu', 'p', 'forwarded', 'nbsp', '99', 'would', '15', '20', 'let', '30', 'statements', '03', 'height', 'day', 'attached', 'farmer', 'c', 'th', 'x', 'also', '+', '02', 'b', '100', 'mail', 'xls', '25', '09', '[', ']', 'like']

# %%
# define features (keywords) of an email
def email_features(email, word_features):
    email_words = set(email)
    features = {}
    
    # NEW FEATURE: Email Length     
    features['length'] = len(email)
    
    # NEW FEATURE: Average Word Length
    lengths = [len(word) for word in email]
    total_length = sum(lengths)
    average_length = total_length / len(email)
    
    features['avg_word_length'] = average_length
    
    # Normal Word Presence as Word Features
    for word in word_features:
        features['V_%s' % word] = (word in email_words)
    
    return features

# %%
# get features sets for each email
featuresets = [(email_features(d, word_features), c) for (d,c) in emaildocs]

# %%
featuresets[1]
# Out:
# ({'length': 172,
#   'avg_word_length': 3.6686046511627906,
#   'V_ect': False,
#   'V_@': True,
#   'V_subject': False,
#   'V_?': True,
#   'V_=': False,
#   "V_'": False,
#   'V_!': False,
#   'V_hou': False,
#   'V_enron': False,
#   'V_;': True,
#   'V_$': False,
#   'V__': False,
#   'V_2000': False,
#   'V_com': True,
#   'V_3': False,
#   'V_>': False,
#   'V_``': False,
#   'V_please': True,
#   'V_1': False,
#   'V_|': False,
#   'V_00': False,
#   'V_2': False,
#   'V_gas': False,
#   'V_*': False,
#   'V_%': False,
#   'V_#': False,
#   'V_deal': False,
#   'V_0': True,
#   'V_http': True,
#   'V_10': False,
#   'V_000': False,
#   'V_e': True,
#   'V_pm': False,
#   'V_meter': False,
#   'V_cc': False,
#   'V_5': False,
#   'V_hpl': False,
#   'V_4': False,
#   'V_new': True,
#   'V_2001': False,
#   'V_company': True,
#   'V_price': False,
#   'V_may': False,
#   'V_get': False,
#   'V_01': False,
#   'V_7': True,
#   'V_information': False,
#   'V_thanks': False,
#   'V_daren': False,
#   'V_corp': False,
#   'V_11': False,
#   'V_need': False,
#   'V_&': False,
#   'V_know': False,
#   'V_email': True,
#   'V_us': False,
#   'V_www': False,
#   'V_time': True,
#   'V_12': False,
#   'V_6': False,
#   'V_font': False,
#   'V_9': True,
#   'V_see': False,
#   'V_one': False,
#   'V_message': True,
#   'V_td': False,
#   'V_8': False,
#   'V_l': False,
#   'V_j': False,
#   'V_mmbtu': False,
#   'V_p': False,
#   'V_forwarded': False,
#   'V_nbsp': False,
#   'V_99': False,
#   'V_would': False,
#   'V_15': False,
#   'V_20': False,
#   'V_let': False,
#   'V_30': False,
#   'V_statements': False,
#   'V_03': False,
#   'V_height': False,
#   'V_day': False,
#   'V_attached': False,
#   'V_farmer': False,
#   'V_c': False,
#   'V_th': True,
#   'V_x': False,
#   'V_also': False,
#   'V_+': True,
#   'V_02': False,
#   'V_b': False,
#   'V_100': False,
#   'V_mail': False,
#   'V_xls': False,
#   'V_25': False,
#   'V_09': False,
#   'V_[': False,
#   'V_]': False,
#   'V_like': False,
#   'V_r': True,
#   'V_production': False,
#   'V_want': False,
#   'V_report': False,
#   'V_sent': False,
#   'V_inc': True,
#   'V_free': False,
#   'V_within': False,
#   'V_05': False,
#   'V_month': False,
#   'V_change': False,
#   'V_energy': True,
#   'V_pec': False,
#   'V_width': False,
#   'V_robert': False,
#   'V_today': False,
#   'V_contact': False,
#   'V_08': True,
#   'V_business': False,
#   'V_sitara': False,
#   'V_forward': False,
#   'V_deals': False,
#   'V_call': False,
#   'V_size': False,
#   'V_nom': False,
#   'V_volume': False,
#   'V_number': False,
#   'V_04': True,
#   'V_go': False,
#   'V_could': False,
#   'V_first': False,
#   'V_make': False,
#   'V_use': True,
#   'V_click': False,
#   'V_contract': False,
#   'V_60': True,
#   'V_list': False,
#   'V_money': False,
#   'V_questions': False,
#   'V_less': False,
#   'V_system': False,
#   'V_texas': False,
#   'V_50': False,
#   'V_net': False,
#   'V_well': False,
#   'V_06': False,
#   'V_u': False,
#   'V_looking': False,
#   'V_best': False,
#   'V_07': False,
#   'V_stock': False,
#   'V_per': False,
#   'V_bob': False,
#   'V_following': False,
#   'V_days': False,
#   'V_back': False,
#   'V_2004': True,
#   'V_24': False,
#   'V_order': False,
#   'V_take': False,
#   'V_28': False,
#   'V_file': False,
#   'V_line': False,
#   'V_internet': False,
#   'V_effective': False,
#   'V_pills': False,
#   'V_daily': False,
#   'V_securities': False,
#   'V_21': False,
#   'V_products': False,
#   'V_available': False,
#   'V_align': False,
#   'V_volumes': False,
#   'V_flow': False,
#   'V_investment': False,
#   'V_oil': False,
#   'V_ticket': False,
#   'V_high': False,
#   'V_product': False,
#   'V_95': False,
#   'V_16': False,
#   'V_service': False,
#   'V_713': False,
#   'V_online': False,
#   'V_office': False,
#   'V_save': False,
#   'V_original': False,
#   'V_31': False,
#   'V_v': False,
#   'V_tr': False,
#   'V_services': False,
#   'V_pt': False,
#   'V_14': False,
#   'V_n': False,
#   'V_name': False,
#   'V_prices': False,
#   'V_future': False,
#   'V_nomination': False,
#   'V_site': False,
#   'V_sale': False,
#   'V_due': False,
#   'V_18': True,
#   'V_news': False,
#   'V_march': False,
#   'V_microsoft': False,
#   'V_market': False,
#   'V_said': False,
#   'V_windows': False,
#   'V_based': False,
#   'V_software': True,
#   'V_ena': False,
#   'V_address': False,
#   'V_br': False,
#   'V_info': False,
#   'V_border': False,
#   'V_thank': False,
#   'V_22': False,
#   'V_g': False,
#   'V_17': False,
#   'V_many': False,
#   'V_international': False,
#   'V_45': False,
#   'V_made': False,
#   'V_help': False,
#   'V_send': False,
#   'V_href': False,
#   'V_69': False,
#   'V_center': False,
#   'V_april': False,
#   'V_sales': False,
#   'V_world': False,
#   'V_mary': False,
#   'V_account': False,
#   'V_professional': False,
#   'V_phone': True,
#   'V_h': False,
#   'V_melissa': False,
#   'V_13': False,
#   'V_home': False,
#   'V_vance': False,
#   'V_purchase': False,
#   'V_f': False,
#   'V_plant': False,
#   'V_two': False,
#   'V_next': False,
#   'V_offer': False,
#   'V_last': False,
#   'V_23': False,
#   'V_without': False,
#   'V_year': False,
#   'V_nd': False,
#   'V_million': False,
#   'V_w': False,
#   'V_week': False,
#   'V_work': False,
#   'V_july': False,
#   'V_agreement': False,
#   'V_40': False,
#   'V_link': False,
#   'V_face': False,
#   'V_june': False,
#   'V_houston': False,
#   'V_find': False,
#   'V_90': False,
#   'V_29': False,
#   'V_src': False,
#   'V_26': False,
#   'V_people': False,
#   'V_19': False,
#   'V_family': False,
#   'V_delivery': False,
#   "V_''": False,
#   'V_group': False,
#   'V_low': False,
#   'V_hours': False,
#   'V_k': False,
#   'V_teco': False,
#   'V_set': False,
#   'V_date': False,
#   'V_computron': False,
#   'V_needs': False,
#   'V_gary': False,
#   'V_look': False,
#   'V_adobe': False,
#   'V_susan': False,
#   'V_reply': True,
#   'V_smith': False,
#   'V_request': False,
#   'V_america': True,
#   'V_january': False,
#   'V_co': False,
#   'V_viagra': False,
#   'V_total': False,
#   'V_good': False,
#   'V_north': False,
#   'V_27': False,
#   'V_xp': False,
#   'V_tap': False,
#   'V_give': False,
#   'V_changes': False,
#   'V_receive': False,
#   'V_companies': False,
#   'V_every': False,
#   'V_style': False,
#   'V_soft': False,
#   'V_right': False,
#   'V_stop': False,
#   'V_think': False,
#   'V_special': False,
#   'V_fax': False,
#   'V_section': False,
#   'V_2003': False,
#   'V_buy': False,
#   'V_hsc': False,
#   'V_120': False,
#   'V_fw': False,
#   'V_check': False,
#   'V_ami': False,
#   'V_color': False,
#   'V_stocks': False,
#   'V_visit': False,
#   'V_part': False,
#   'V_show': False,
#   'V_web': False,
#   'V_cialis': False,
#   'V_lisa': False,
#   'V_even': False,
#   'V_desk': False,
#   'V_way': False,
#   'V_trade': False,
#   'V_act': False,
#   'V_advice': False,
#   'V_much': False,
#   'V_management': False,
#   'V_security': False,
#   'V_63': False,
#   'V_cotten': False,
#   'V_taylor': False,
#   'V_top': False,
#   'V_sure': False,
#   'V_david': False,
#   'V_megan': False,
#   'V_tenaska': False,
#   'V_html': False,
#   'V_long': False,
#   'V_98': False,
#   'V_provide': False,
#   'V_keep': False,
#   'V_80': False,
#   'V_remove': False,
#   'V_end': False,
#   'V_julie': False,
#   'V_performance': False,
#   'V_id': False,
#   'V_hi': False,
#   'V_great': False,
#   'V_actuals': False,
#   'V_currently': False,
#   'V_via': False,
#   'V_content': False,
#   'V_works': False,
#   'V_george': False,
#   'V_quality': False,
#   'V_results': False,
#   'V_august': False,
#   'V_still': False,
#   'V_spot': False,
#   'V_shares': False,
#   'V_pay': False,
#   'V_actual': False,
#   'V_china': False,
#   'V_michael': False,
#   'V_must': False,
#   'V_161': False,
#   'V_corporation': False,
#   'V_december': True,
#   'V_going': False,
#   'V_index': False,
#   'V_44': False,
#   'V_\x01': False,
#   'V_place': False,
#   'V_received': False,
#   'V_program': False,
#   'V_increase': False,
#   'V_friday': False,
#   'V_rate': False,
#   'V_process': False,
#   'V_dollars': False,
#   'V_current': False,
#   'V_come': False,
#   'V_customers': False,
#   'V_needed': False,
#   'V_voip': False,
#   'V_details': True,
#   'V_believe': False,
#   'V_500': False,
#   'V_copy': False,
#   'V_32': False,
#   'V_term': False,
#   'V_using': False,
#   'V_offers': False,
#   'V_better': False,
#   'V_resources': False,
#   'V_duke': False,
#   'V_able': False,
#   'V_mark': False,
#   'V_read': False,
#   'V_real': False,
#   'V_team': False,
#   'V_`': False,
#   'V_cd': False,
#   'V_including': False,
#   'V_steve': False,
#   'V_note': False,
#   'V_iv': False,
#   'V_september': False,
#   'V_limited': False,
#   'V_st': False,
#   'V_entered': False,
#   'V_chokshi': False,
#   'V_brian': False,
#   'V_ms': False,
#   'V_full': False,
#   'V_fee': False,
#   'V_since': False,
#   'V_start': False,
#   'V_control': False,
#   'V_possible': False,
#   'V_technology': False,
#   'V_access': False,
#   'V_fuel': True,
#   'V_cost': False,
#   'V_graves': False,
#   'V_customer': False,
#   'V_prior': False,
#   'V_php': False,
#   'V_fyi': False,
#   'V_notice': False,
#   'V_unify': False,
#   'V_activity': False,
#   'V_prescription': False,
#   'V_paliourg': False,
#   'V_thursday': False,
#   'V_problem': False,
#   'V_point': False,
#   'V_regards': False,
#   'V_created': False,
#   'V_sell': False,
#   'V_eastrans': False,
#   'V_tickets': False,
#   'V_february': False,
#   'V_got': False,
#   'V_always': False,
#   'V_past': False,
#   'V_pro': False,
#   'V_trading': False,
#   'V_feb': False,
#   'V_revised': False,
#   'V_used': False,
#   'V_tom': False,
#   'V_gif': False,
#   'V_provided': False,
#   'V_little': False,
#   'V_party': False,
#   'V_fact': False,
#   'V_oo': False,
#   'V_include': False,
#   'V_either': False,
#   'V_type': False,
#   'V_jackie': False,
#   'V_interest': False,
#   'V_support': False,
#   'V_another': False,
#   'V_transport': False,
#   'V_newsletter': False,
#   'V_october': False,
#   'V_investing': False,
#   'V_bgcolor': False,
#   'V_suite': False,
#   'V_issue': False,
#   'V_paid': False,
#   'V_manager': False,
#   'V_review': False,
#   'V_mobile': True,
#   'V_meds': False,
#   'V_pat': False,
#   'V_years': False,
#   'V_counterparty': False,
#   'V_noms': False,
#   'V_36': False,
#   'V_months': False,
#   'V_na': False,
#   'V_retail': False,
#   'V_2005': False,
#   'V_natural': False,
#   'V_zone': False,
#   'V_server': False,
#   'V_wellhead': False,
#   'V_estimates': False,
#   'V_data': False,
#   'V_soon': False,
#   'V_tu': False,
#   'V_exchange': False,
#   'V_middle': False,
#   'V_computer': False,
#   'V_continue': False,
#   'V_create': True,
#   'V_ces': False,
#   'V_35': False,
#   'V_someone': False,
#   'V_never': False,
#   'V_easy': False,
#   'V_global': False,
#   'V_regarding': False,
#   'V_young': False,
#   'V_credit': False,
#   'V_financial': False,
#   'V_image': False,
#   'V_events': False,
#   'V_put': False,
#   'V_john': False,
#   'V_love': False,
#   'V_life': False,
#   'V_risk': False,
#   'V_feel': False,
#   'V_city': False,
#   'V_tabs': False,
#   'V_valign': False,
#   'V_aimee': False,
#   'V_moopid': False,
#   'V_hotlist': False,
#   'V_second': False,
#   'V_power': False,
#   'V_registered': False,
#   'V_tx': False,
#   'V_field': False,
#   'V_img': False,
#   'V_watch': False,
#   'V_however': False,
#   'V_states': True,
#   'V_move': False,
#   'V_position': False,
#   'V_complete': False,
#   'V_rates': False,
#   'V_additional': False,
#   'V_shipping': False,
#   'V_marketing': False,
#   'V_pg': False,
#   'V_tuesday': False,
#   'V_november': False,
#   'V_55': False,
#   'V_dec': True,
#   'V_three': False,
#   'V_ls': False,
#   'V_demand': False,
#   'V_de': False,
#   'V_page': False,
#   'V_man': False,
#   'V_pefs': False,
#   'V_technologies': True,
#   'V_person': False,
#   'V_wish': False,
#   'V_mg': False,
#   'V_worldwide': False,
#   'V_already': False,
#   'V_rita': False,
#   'V_monday': False,
#   'V_numbers': False,
#   'V_cash': False,
#   'V_operating': False,
#   'V_box': False,
#   'V_drugs': False,
#   'V_thru': False,
#   'V_getting': False,
#   'V_hplc': False,
#   'V_anything': False,
#   'V_jan': False,
#   'V_meyers': False,
#   'V_expectations': False,
#   'V_employees': False,
#   'V_follow': False,
#   'V_supply': False,
#   'V_james': False,
#   'V_old': False,
#   'V_required': False,
#   'V_transaction': False,
#   'V_website': False,
#   'V_area': False,
#   'V_application': False,
#   'V_done': False,
#   'V_might': False,
#   'V_transfer': False,
#   'V_super': False,
#   'V_called': False,
#   'V_action': False,
#   'V_pipeline': False,
#   'V_knle': False,
#   'V_united': True,
#   'V_48': False,
#   'V_unsubscribe': False,
#   'V_firm': False,
#   'V_cause': False,
#   'V_pain': False,
#   'V_risks': False,
#   'V_colspan': False,
#   'V_mr': False,
#   'V_version': True,
#   'V_industry': False,
#   'V_wynne': False,
#   'V_country': False,
#   'V_nominations': False,
#   'V_strong': False,
#   'V_terms': False,
#   'V_update': False,
#   'V_try': False,
#   'V_calls': False,
#   'V_photoshop': False,
#   'V_meters': False,
#   'V_ever': False,
#   'V_error': False,
#   'V_development': False,
#   'V_project': False,
#   'V_important': False,
#   'V_39': False,
#   'V_operations': False,
#   'V_txu': False,
#   'V_differ': False,
#   'V_coastal': False,
#   'V_removed': False,
#   'V_enter': False,
#   'V_utilities': False,
#   'V_everyone': False,
#   'V_brand': False,
#   'V_text': False,
#   'V_spam': False,
#   'V_working': False,
#   'V_hplno': False,
#   'V_75': False,
#   'V_images': False,
#   'V_\\': False,
#   'V_spreadsheet': False,
#   'V_major': False,
#   'V_expect': False,
#   'V_canada': False,
#   'V_pricing': False,
#   'V_charge': False,
#   'V_payment': False,
#   'V_release': False,
#   'V_accounting': False,
#   'V_70': False,
#   'V_small': False,
#   'V_200': False,
#   'V_deliveries': False,
#   'V_remember': False,
#   'V_jones': False,
#   'V_mx': False,
#   'V_biz': True,
#   'V_doc': False,
#   'V_sex': False,
#   'V_open': False,
#   'V_lee': False,
#   'V_material': False,
#   'V_private': False,
#   'V_ready': False,
#   'V_plans': False,
#   'V_gcs': False,
#   'V_cec': False,
#   'V_contracts': False,
#   'V_big': False,
#   'V_amount': False,
#   'V_wednesday': False,
#   'V_everything': False,
#   'V_third': False,
#   'V_add': False,
#   'V_iferc': False,
#   'V_potential': False,
#   'V_parker': False,
#   'V_hope': False,
#   'V_public': False,
#   'V_confirm': False,
#   'V_health': False,
#   'V_away': False,
#   'V_view': False,
#   'V_words': False,
#   'V_jpg': False,
#   'V_network': False,
#   'V_donald': True,
#   'V_form': False,
#   'V_meet': False,
#   'V_kind': False,
#   'V_features': False,
#   'V_really': False,
#   'V_state': False,
#   'V_uncertainties': False,
#   'V_al': False,
#   'V_storage': False,
#   'V_letter': False,
#   'V_download': False,
#   'V_something': False,
#   'V_bank': False,
#   'V_scheduled': False,
#   'V_52': False,
#   'V_around': False,
#   'V_anyone': False,
#   'V_things': False,
#   'V_correct': False,
#   'V_cf': False,
#   'V_85': False,
#   'V_sources': False,
#   'V_final': False,
#   'V_case': False,
#   'V_expected': False,
#   'V_necessary': False,
#   'V_certain': False,
#   'V_clynes': False,
#   'V_solution': False,
#   'V_friends': False,
#   'V_federal': False,
#   'V_mike': False,
#   'V_offering': False,
#   'V_personal': False,
#   'V_table': False,
#   'V_users': False,
#   'V_htmlimg': False,
#   'V_department': False,
#   'V_found': False,
#   'V_im': False,
#   'V_yet': False,
#   'V_quick': False,
#   'V_browser': False,
#   'V_latest': False,
#   'V_reinhardt': False,
#   'V_code': False,
#   'V_darren': False,
#   'V_·': False,
#   'V_wi': False,
#   'V_~': False,
#   'V_hplo': False,
#   'V_124': False,
#   'V_enronxgate': False,
#   'V_reason': False,
#   'V_systems': True,
#   'V_direct': False,
#   'V_47': False,
#   'V_sat': False,
#   'V_subscribers': False,
#   'V_epson': False,
#   'V_issues': False,
#   'V_loss': False,
#   'V_sherlyn': False,
#   'V_music': False,
#   'V_growth': False,
#   'V_user': False,
#   'V_ask': False,
#   'V_meeting': False,
#   'V_god': False,
#   'V_advise': False,
#   'V_richard': False,
#   'V_lloyd': False,
#   'V_valid': False,
#   'V_taking': False,
#   'V_weeks': False,
#   'V_south': False,
#   'V_involve': False,
#   'V_vlt': False,
#   'V_300': False,
#   'V_interested': False,
#   'V_albrecht': False,
#   'V_secure': False,
#   'V_featured': False,
#   'V_period': False,
#   'V_delta': False,
#   'V_weissman': False,
#   'V_katherine': False,
#   'V_safe': False,
#   'V_zero': False,
#   'V_body': False,
#   'V_location': False,
#   'V_press': False,
#   'V_weekend': False,
#   'V_impact': False,
#   'V_intended': False,
#   'V_fill': False,
#   'V_corel': False,
#   'V_men': False,
#   'V_54': False,
#   'V_ltd': False,
#   'V_generic': False,
#   'V_cheap': False,
#   'V_el': False,
#   'V_card': False,
#   'V_prize': False,
#   'V_0310041': False,
#   'V_late': False,
#   'V_opportunity': False,
#   'V_gr': False,
#   'V_times': False,
#   'V_katy': False,
#   'V_sun': False,
#   'V_large': False,
#   'V_meaning': False,
#   'V_given': False,
#   'V_write': False,
#   'V_considered': False,
#   'V_book': False,
#   'V_pc': False,
#   'V_medical': False,
#   'V_morning': False,
#   'V_revision': False,
#   'V_travel': False,
#   'V_aol': False,
#   'V_projections': False,
#   'V_producer': False,
#   'V_hello': False,
#   'V_macromedia': False,
#   'V_cds': False,
#   'V_wanted': False,
#   'V_begin': False,
#   'V_calpine': False,
#   'V_donna': False,
#   'V_director': False,
#   'V_discount': False,
#   'V_express': False,
#   'V_thought': False,
#   'V_source': False,
#   'V_duty': False,
#   'V_compliance': False,
#   'V_paste': False,
#   'V_gathering': False,
#   'V_left': False,
#   'V_extended': False,
#   'V_capital': False,
#   'V_div': False,
#   'V_rolex': False,
#   'V_iit': False,
#   'V_demokritos': False,
#   'V_longer': False,
#   'V_hey': False,
#   'V_shut': False,
#   'V_night': False,
#   'V_recent': False,
#   'V_readers': False,
#   'V_portfolio': False,
#   'V_updated': False,
#   'V_971': False,
#   'V_else': False,
#   'V_aware': False,
#   'V_approved': False,
#   'V_factors': False,
#   'V_publisher': False,
#   'V_options': False,
#   'V_edition': False,
#   'V_0424040': False,
#   'V_ftar': False,
#   'V_bring': False,
#   'V_close': False,
#   'V_immediately': False,
#   'V_fast': False,
#   'V_related': False,
#   'V_mentioned': False,
#   'V_59': False,
#   'V_reports': False,
#   'V_ic': False,
#   'V_carlos': False,
#   'V_42': False,
#   'V_plan': False,
#   'V_acton': False,
#   'V_care': False,
#   'V_lose': False,
#   'V_girls': False,
#   'V_experience': False,
#   'V_bill': False,
#   'V_howard': False,
#   'V_included': False,
#   'V_perfect': False,
#   'V_ship': False,
#   'V_dear': False,
#   'V_several': False,
#   'V_agree': False,
#   'V_investors': False,
#   'V_play': False,
#   'V_say': False,
#   'V_ali': False,
#   'V_title': False,
#   'V_clear': False,
#   'V_lsk': False,
#   'V_voice': False,
#   'V_side': False,
#   'V_sept': False,
#   'V_problems': False,
#   'V_56': False,
#   'V_target': False,
#   'V_air': False,
#   'V_logistics': False,
#   'V_distribution': False,
#   'V_digital': False,
#   'V_basin': False,
#   'V_cut': False,
#   'V_facility': False,
#   'V_commercial': False,
#   'V_hanks': False,
#   'V_38': False,
#   'V_reserves': False,
#   'V_central': False,
#   'V_nothing': False,
#   'V_profile': False,
#   'V_key': False,
#   'V_rodriguez': False,
#   'V_6353': False,
#   'V_neal': False,
#   'V_thing': False,
#   'V_orders': False,
#   'V_others': False,
#   'V_800': False,
#   'V_four': False,
#   'V_run': False,
#   'V_000000': False,
#   'V_agent': False,
#   'V_ability': False,
#   'V_entex': False,
#   'V_lannou': False,
#   'V_49': False,
#   'V_fixed': False,
#   'V_normally': False,
#   'V_publication': False,
#   'V_physical': False,
#   'V_drive': False,
#   'V_schedule': False,
#   'V_become': False,
#   'V_swing': False,
#   'V_different': False,
#   'V_hot': False,
#   'V_increased': False,
#   'V_advantage': False,
#   'V_tell': False,
#   'V_requirements': False,
#   'V_poorman': False,
#   'V_added': False,
#   'V_fuels': False,
#   'V_says': False,
#   'V_cover': False,
#   'V_head': False,
#   'V_projects': False,
#   'V_basis': False,
#   'V_items': False,
#   'V_pharmacy': False,
#   'V_yahoo': False,
#   'V_video': False,
#   'V_claim': False,
#   'V_short': False,
#   'V_channel': False,
#   'V_value': False,
#   'V_eol': False,
#   'V_success': False,
#   'V_camp': False,
#   'V_baumbach': False,
#   'V_therefore': False,
#   'V_hard': False,
#   'V_lst': False,
#   'V_addition': False,
#   'V_rnd': False,
#   'V_matter': False,
#   'V_tel': False,
#   'V_format': False,
#   'V_taken': False,
#   'V_beaumont': False,
#   'V_requested': False,
#   'V_htm': False,
#   'V_jennifer': False,
#   'V_scott': False,
#   'V_hesse': False,
#   'V_clem': False,
#   'V_talk': False,
#   'V_dy': False,
#   'V_stack': False,
#   'V_broadband': False,
#   'V_plus': False,
#   'V_includes': False,
#   'V_legal': False,
#   'V_survey': False,
#   'V_victor': False,
#   'V_etc': False,
#   'V_handle': False,
#   'V_weight': False,
#   'V_making': False,
#   'V_later': False,
#   'V_wells': False,
#   'V_approval': False,
#   'V_national': False,
#   'V_alt': False,
#   'V_usb': False,
#   'V_priced': False,
#   'V_confirmation': False,
#   'V_cotton': False,
#   'V_track': False,
#   'V_bridge': False,
#   'V_bad': False,
#   'V_methanol': False,
#   ...},
#  'spam')

# %%
# training the model using Naive Bayes classifier with a 90/10 split

# Set the seed for reproducibility
random.seed(9)

# Shuffle the data
random.shuffle(featuresets)

# Calculate the split index
split_index = int(len(featuresets) * 0.9)

# Split the data into training and testing sets
train_set = featuresets[:split_index]
test_set = featuresets[split_index:]

# Print the number of samples in each set
print(f'Number of training samples: {len(train_set)}')
print(f'Number of testing samples: {len(test_set)}')

classifier = nltk.NaiveBayesClassifier.train(train_set)

# evaluate the accuracy of the classifier
print (f'Classifier Accuracy: {nltk.classify.accuracy(classifier, test_set)}')
# Out:
# Number of training samples: 1800
# Number of testing samples: 200
# Classifier Accuracy: 0.935

# %%
# Make predictions on the test set
test_features = [feat for feat, label in test_set]
true_labels = [label for feat, label in test_set]
predicted_labels = [classifier.classify(feat) for feat in test_features]

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
print("Confusion Matrix:")
print(conf_matrix)

# Classification report for more detailed metrics
print("\nClassification Report:")
print(classification_report(true_labels, predicted_labels))
# Out:
# Confusion Matrix:
# [[99 13]
#  [ 0 88]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          ham       1.00      0.88      0.94       112
#         spam       0.87      1.00      0.93        88
#
#     accuracy                           0.94       200
#    macro avg       0.94      0.94      0.93       200
# weighted avg       0.94      0.94      0.94       200

# %% [markdown]
# #### This last model proved to be the most effective, with 96.5% accuracy.
